# %%
import numpy as np
import pandas as pd
import re, string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC
import xgboost as xgb
import gc
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy
import multiprocessing

# %%
dtypes = {
    'comment_text'   : np.unicode ,
    'toxic':         np.int16, 
    'severe_toxic': np.int16,
    'obscene': np.int16,
    'threat': np.int16,
    'insult': np.int16,
    'identity_hate': np.int16
}

train = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/train.csv', dtype=dtypes, encoding='utf-8')
test = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/test.csv', dtype=dtypes, encoding='utf-8')

train.comment_text.fillna("unknown", inplace=True)
test.comment_text.fillna("unknown",  inplace=True)

subm = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/sample_submission.csv')    
submid = pd.DataFrame({'id': subm["id"].values.astype(str)}, dtype=np.str)

# %%
# Tokenization

re_tok = re.compile(u'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')

def tokenize(s):
    return re_tok.sub(r' \1 ', s).split()

# %% [markdown]
# ### Google Word2Vec

# %%
# # Convertion of .bin to .txt file
# from gensim.models.keyedvectors import KeyedVectors

# model = KeyedVectors.load_word2vec_format('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Datasets/GoogleNews-vectors-negative300.bin', binary=True)
# model.save_word2vec_format('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/GoogleNews-vectors-negative300.txt', binary=False)

# %%
train_mes, valid_mes, train_l, valid_l = train_test_split(train['comment_text'],
                                                          train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']],
                                                          test_size=0.2, random_state=42)
train_mes = pd.DataFrame(train_mes)
valid_mes = pd.DataFrame(valid_mes)

# %%
# load the Google word2vec vectors in a dictionary:
from tqdm import tqdm

embeddings_index_google = {}
f = open('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/GoogleNews-vectors-negative300.txt', encoding='utf-8')
for line in tqdm(f):
    values = line.split()
    word = values[0]
    try:
        coefs = np.asarray(values[1:], dtype='float32')
    except:
        continue
    embeddings_index_google[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index_google))
# Out:
# 3000001it [05:55, 8430.19it/s]
# Found 3000000 word vectors.

# %%
# Function to create a normalized vector for the whole sentence
def sent2vec(s, embeddings_index):
    words = str(s).lower()
    words = tokenize(words)
    words = [w for w in words if w.isalpha()]
    M = []
    for w in words:
        try:
            M.append(embeddings_index[w])
        except:
            continue
    M = np.array(M)
    v = M.sum(axis=0)
    if type(v) != np.ndarray:
        return np.zeros(300)
    return v / np.sqrt((v ** 2).sum())

# %%
gc.collect()

# Create sentence vectors using the above function for training and validation set
xtrain_google = [sent2vec(x, embeddings_index_google) for x in train_mes['comment_text']]
xvalid_google = [sent2vec(x, embeddings_index_google) for x in valid_mes['comment_text']]

xtrain_google = np.array(xtrain_google)
xvalid_google = np.array(xvalid_google)

print("xtrain_google.shape = ", xtrain_google.shape)
print("xvalid_google.shape = ", xvalid_google.shape)
 
# Generate Word vectors of test data
xtest_google = [sent2vec(x, embeddings_index_google) for x in test['comment_text']]
xtest_google = np.array(xtest_google)
# Out:
# xtrain_google.shape =  (127656, 300)
# xvalid_google.shape =  (31915, 300)

# %% [markdown]
# ### SGD Classifier

# %%
scores = []
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((valid_mes.shape[0], len(col))).astype(object)

for i, class_name in enumerate(col):
    print('fit '+ class_name)
    classifier = SGDClassifier(loss='log', max_iter=1000, epsilon=0.001, n_jobs=-1)

    cv_score = np.mean(cross_val_score(classifier, xtrain_google, train_l[class_name], cv=5, scoring='roc_auc'))
    scores.append(cv_score)
    print('CV score for class {} is {}'.format(class_name, cv_score))

    classifier.fit(xtrain_google, train_l[class_name])
    preds[:,i] = classifier.predict_proba(xvalid_google)[:,1]
    
    val_score = classifier.score(xvalid_google, valid_l[class_name])
    print('Validation score for class {} is {}'.format(class_name, val_score))
    
print('\nTotal CV score is {}'.format(np.mean(scores)))
# Out:
# fit toxic
# CV score for class toxic is 0.7786467063271928
# Validation score for class toxic is 0.9083816387278709
# fit severe_toxic
# CV score for class severe_toxic is 0.9124718212335095
# Validation score for class severe_toxic is 0.989942033526555
# fit obscene
# CV score for class obscene is 0.8248545995381784
# Validation score for class obscene is 0.9483941720194266
# fit threat
# CV score for class threat is 0.866430355253675
# Validation score for class threat is 0.9976813410621964
# fit insult
# CV score for class insult is 0.8221718870514358
# Validation score for class insult is 0.9505561648127839
# fit identity_hate
# CV score for class identity_hate is 0.8154681296369934
# Validation score for class identity_hate is 0.9907880307065643
#
# Total CV score is 0.8366739165068308

# %%
testpreds_google = np.zeros((test.shape[0], len(col)))
for i, class_name in enumerate(col):
    print('fit '+ class_name)
    testpreds_google[:,i] = classifier.predict_proba(xtest_google)[:,1]
    
submission = pd.concat([submid, pd.DataFrame(testpreds_google, columns = col)], axis=1)
submission.to_csv('sample_submission_google_sgd.csv', index=False)
# Out:
# fit toxic
# fit severe_toxic
# fit obscene
# fit threat
# fit insult
# fit identity_hate

# %% [markdown]
# ### Logistic Regression Classifier

# %%
scores = []
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((valid_mes.shape[0], len(col))).astype(object)

for i, class_name in enumerate(col):
    print('fit '+ class_name)
    classifier = LogisticRegression(C=0.1, solver='sag')
#    classifier = SVC(C=1.0, probability=True)

    cv_score = np.mean(cross_val_score(classifier, xtrain_google, train_l[class_name], cv=5, scoring='roc_auc'))
    scores.append(cv_score)
    print('CV score for class {} is {}'.format(class_name, cv_score))

    classifier.fit(xtrain_google, train_l[class_name])
    preds[:,i] = classifier.predict_proba(xvalid_google)[:,1]
    
    val_score = classifier.score(xvalid_google, valid_l[class_name])
    print('Validation score for class {} is {}'.format(class_name, val_score))

print('\nTotal CV score is {}'.format(np.mean(scores)))
# Out:
# fit toxic
# CV score for class toxic is 0.7788775217940127
# Validation score for class toxic is 0.9090396365345449
# fit severe_toxic
# CV score for class severe_toxic is 0.9125470180252113
# Validation score for class severe_toxic is 0.989942033526555
# fit obscene
# CV score for class obscene is 0.8250653768834013
# Validation score for class obscene is 0.9488641704527652
# fit threat
# CV score for class threat is 0.8665649806444659
# Validation score for class threat is 0.9976813410621964
# fit insult
# CV score for class insult is 0.8224004324908399
# Validation score for class insult is 0.9505561648127839
# fit identity_hate
# CV score for class identity_hate is 0.8155420763991653
# Validation score for class identity_hate is 0.9907880307065643
#
# Total CV score is 0.836832901039516

# %%
testpreds_google = np.zeros((test.shape[0], len(col)))
for i, class_name in enumerate(col):
    print('fit '+ class_name)
    testpreds_google[:,i] = classifier.predict_proba(xtest_google)[:,1]
    
submission = pd.concat([submid, pd.DataFrame(testpreds_google, columns = col)], axis=1)
submission.to_csv('sample_submission_google_logit.csv', index=False)
# Out:
# fit toxic
# fit severe_toxic
# fit obscene
# fit threat
# fit insult
# fit identity_hate

# %%
scores = []
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((valid_mes.shape[0], len(col))).astype(object)

for i, class_name in enumerate(col):
    print('fit '+ class_name)
    classifier = SVC(C=1.0, probability=True)

    cv_score = np.mean(cross_val_score(classifier, xtrain_google, train_l[class_name], cv=5, scoring='roc_auc'))
    scores.append(cv_score)
    print('CV score for class {} is {}'.format(class_name, cv_score))

    classifier.fit(xtrain_google, train_l[class_name])
    preds[:,i] = classifier.predict_proba(xvalid_google)[:,1]
    
    val_score = classifier.score(xvalid_google, valid_l[class_name])
    print('Validation score for class {} is {}'.format(class_name, val_score))

print('Total CV score is {}'.format(np.mean(scores)))
# Out:
# fit toxic

# %%
testpreds_google = np.zeros((test.shape[0], len(col)))
for i, class_name in enumerate(col):
    print('fit '+ class_name)
    testpreds_google[:,i] = classifier.predict_proba(xtest_google)[:,1]
    test_score = classifier.score(xtest_google)
    
submission = pd.concat([submid, pd.DataFrame(testpreds_google, columns = col)], axis=1)
submission.to_csv('sample_submission_google_svc.csv', index=False)

# %% [markdown]
# ### XGBoost Classifier

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=2017, num_rounds=500):
    param = {}
    param['objective'] = 'binary:logistic'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['eval_metric'] = 'auc'
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'valid') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    return model

# %%
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((test.shape[0], len(col)))

for i, j in enumerate(col):
    print('fit '+j)
    model = runXGB(xtrain_google, train_l[j], xvalid_google, valid_l[j])
    preds[:,i] = model.predict(xgb.DMatrix(xtest_google), ntree_limit = model.best_ntree_limit)
    gc.collect()
# Out:
# fit toxic
# [0]	train-auc:0.77237	valid-auc:0.76232
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79239	valid-auc:0.77890
# [2]	train-auc:0.79949	valid-auc:0.78562
# [3]	train-auc:0.80285	valid-auc:0.78797
# [4]	train-auc:0.80881	valid-auc:0.79109
# [5]	train-auc:0.81184	valid-auc:0.79236
# [6]	train-auc:0.81453	valid-auc:0.79402
# [7]	train-auc:0.81656	valid-auc:0.79526
# [8]	train-auc:0.81886	valid-auc:0.79620
# [9]	train-auc:0.82152	valid-auc:0.79765
# [10]	train-auc:0.82240	valid-auc:0.79817
# [11]	train-auc:0.82398	valid-auc:0.79936
# [12]	train-auc:0.82595	valid-auc:0.80060
# [13]	train-auc:0.82786	valid-auc:0.80204
# [14]	train-auc:0.82911	valid-auc:0.80300
# [15]	train-auc:0.83077	valid-auc:0.80427
# [16]	train-auc:0.83280	valid-auc:0.80630
# [17]	train-auc:0.83425	valid-auc:0.80722
# [18]	train-auc:0.83605	valid-auc:0.80855
# [19]	train-auc:0.83673	valid-auc:0.80883
# [20]	train-auc:0.83820	valid-auc:0.80948
# [21]	train-auc:0.83962	valid-auc:0.81044
# [22]	train-auc:0.84057	valid-auc:0.81072
# [23]	train-auc:0.84193	valid-auc:0.81140
# [24]	train-auc:0.84347	valid-auc:0.81282
# [25]	train-auc:0.84501	valid-auc:0.81345
# [26]	train-auc:0.84621	valid-auc:0.81391
# [27]	train-auc:0.84758	valid-auc:0.81500
# [28]	train-auc:0.84909	valid-auc:0.81537
# [29]	train-auc:0.85051	valid-auc:0.81632
# [30]	train-auc:0.85172	valid-auc:0.81647
# [31]	train-auc:0.85298	valid-auc:0.81707
# [32]	train-auc:0.85438	valid-auc:0.81791
# [33]	train-auc:0.85560	valid-auc:0.81863
# [34]	train-auc:0.85704	valid-auc:0.81926
# [35]	train-auc:0.85832	valid-auc:0.81997
# [36]	train-auc:0.85944	valid-auc:0.82076
# [37]	train-auc:0.86079	valid-auc:0.82119
# [38]	train-auc:0.86206	valid-auc:0.82207
# [39]	train-auc:0.86337	valid-auc:0.82235
# [40]	train-auc:0.86457	valid-auc:0.82284
# [41]	train-auc:0.86601	valid-auc:0.82349
# [42]	train-auc:0.86713	valid-auc:0.82376
# [43]	train-auc:0.86850	valid-auc:0.82462
# [44]	train-auc:0.86945	valid-auc:0.82516
# [45]	train-auc:0.87064	valid-auc:0.82569
# [46]	train-auc:0.87192	valid-auc:0.82626
# [47]	train-auc:0.87308	valid-auc:0.82704
# [48]	train-auc:0.87423	valid-auc:0.82762
# [49]	train-auc:0.87532	valid-auc:0.82828
# [50]	train-auc:0.87642	valid-auc:0.82886
# [51]	train-auc:0.87725	valid-auc:0.82917
# [52]	train-auc:0.87816	valid-auc:0.82961
# [53]	train-auc:0.87905	valid-auc:0.82997
# [54]	train-auc:0.87990	valid-auc:0.83032
# [55]	train-auc:0.88084	valid-auc:0.83046
# [56]	train-auc:0.88179	valid-auc:0.83070
# [57]	train-auc:0.88294	valid-auc:0.83112
# [58]	train-auc:0.88341	valid-auc:0.83149
# [59]	train-auc:0.88421	valid-auc:0.83157
# [60]	train-auc:0.88514	valid-auc:0.83169
# [61]	train-auc:0.88602	valid-auc:0.83227
# [62]	train-auc:0.88678	valid-auc:0.83257
# [63]	train-auc:0.88768	valid-auc:0.83317
# [64]	train-auc:0.88854	valid-auc:0.83342
# [65]	train-auc:0.88953	valid-auc:0.83345
# [66]	train-auc:0.89016	valid-auc:0.83373
# [67]	train-auc:0.89104	valid-auc:0.83398
# [68]	train-auc:0.89200	valid-auc:0.83423
# [69]	train-auc:0.89251	valid-auc:0.83434
# [70]	train-auc:0.89308	valid-auc:0.83474
# [71]	train-auc:0.89376	valid-auc:0.83497
# [72]	train-auc:0.89477	valid-auc:0.83527
# [73]	train-auc:0.89549	valid-auc:0.83554
# [74]	train-auc:0.89604	valid-auc:0.83593
# [75]	train-auc:0.89680	valid-auc:0.83622
# [76]	train-auc:0.89764	valid-auc:0.83644
# [77]	train-auc:0.89850	valid-auc:0.83675
# [78]	train-auc:0.89927	valid-auc:0.83708
# [79]	train-auc:0.89990	valid-auc:0.83724
# [80]	train-auc:0.90060	valid-auc:0.83734
# [81]	train-auc:0.90101	valid-auc:0.83740
# [82]	train-auc:0.90152	valid-auc:0.83771
# [83]	train-auc:0.90210	valid-auc:0.83800
# [84]	train-auc:0.90277	valid-auc:0.83805
# [85]	train-auc:0.90330	valid-auc:0.83808
# [86]	train-auc:0.90402	valid-auc:0.83831
# [87]	train-auc:0.90459	valid-auc:0.83837
# [88]	train-auc:0.90483	valid-auc:0.83846
# [89]	train-auc:0.90551	valid-auc:0.83874
# [90]	train-auc:0.90624	valid-auc:0.83889
# [91]	train-auc:0.90687	valid-auc:0.83900
# [92]	train-auc:0.90748	valid-auc:0.83921
# [93]	train-auc:0.90772	valid-auc:0.83931
# [94]	train-auc:0.90833	valid-auc:0.83942
# [95]	train-auc:0.90903	valid-auc:0.83948
# [96]	train-auc:0.90961	valid-auc:0.83967
# [97]	train-auc:0.91032	valid-auc:0.83978
# [98]	train-auc:0.91092	valid-auc:0.83986
# [99]	train-auc:0.91165	valid-auc:0.83996
# [100]	train-auc:0.91237	valid-auc:0.84021
# [101]	train-auc:0.91289	valid-auc:0.84036
# [102]	train-auc:0.91358	valid-auc:0.84035
# [103]	train-auc:0.91407	valid-auc:0.84032
# [104]	train-auc:0.91447	valid-auc:0.84054
# [105]	train-auc:0.91509	valid-auc:0.84062
# [106]	train-auc:0.91579	valid-auc:0.84081
# [107]	train-auc:0.91626	valid-auc:0.84091
# [108]	train-auc:0.91665	valid-auc:0.84105
# [109]	train-auc:0.91720	valid-auc:0.84136
# [110]	train-auc:0.91783	valid-auc:0.84135
# [111]	train-auc:0.91831	valid-auc:0.84146
# [112]	train-auc:0.91871	valid-auc:0.84151
# [113]	train-auc:0.91919	valid-auc:0.84153
# [114]	train-auc:0.91975	valid-auc:0.84156
# [115]	train-auc:0.92025	valid-auc:0.84162
# [116]	train-auc:0.92063	valid-auc:0.84173
# [117]	train-auc:0.92103	valid-auc:0.84185
# [118]	train-auc:0.92151	valid-auc:0.84186
# [119]	train-auc:0.92203	valid-auc:0.84172
# [120]	train-auc:0.92243	valid-auc:0.84183
# [121]	train-auc:0.92278	valid-auc:0.84186
# [122]	train-auc:0.92334	valid-auc:0.84190
# [123]	train-auc:0.92370	valid-auc:0.84187
# [124]	train-auc:0.92415	valid-auc:0.84203
# [125]	train-auc:0.92463	valid-auc:0.84216
# [126]	train-auc:0.92506	valid-auc:0.84227
# [127]	train-auc:0.92538	valid-auc:0.84244
# [128]	train-auc:0.92578	valid-auc:0.84247
# [129]	train-auc:0.92634	valid-auc:0.84268
# [130]	train-auc:0.92688	valid-auc:0.84284
# [131]	train-auc:0.92743	valid-auc:0.84282
# [132]	train-auc:0.92777	valid-auc:0.84296
# [133]	train-auc:0.92793	valid-auc:0.84299
# [134]	train-auc:0.92827	valid-auc:0.84325
# [135]	train-auc:0.92854	valid-auc:0.84338
# [136]	train-auc:0.92907	valid-auc:0.84351
# [137]	train-auc:0.92929	valid-auc:0.84369
# [138]	train-auc:0.92948	valid-auc:0.84373
# [139]	train-auc:0.92986	valid-auc:0.84378
# [140]	train-auc:0.93012	valid-auc:0.84381
# [141]	train-auc:0.93053	valid-auc:0.84386
# [142]	train-auc:0.93096	valid-auc:0.84381
# [143]	train-auc:0.93135	valid-auc:0.84377
# [144]	train-auc:0.93175	valid-auc:0.84395
# [145]	train-auc:0.93224	valid-auc:0.84394
# [146]	train-auc:0.93256	valid-auc:0.84401
# [147]	train-auc:0.93293	valid-auc:0.84392
# [148]	train-auc:0.93317	valid-auc:0.84399
# [149]	train-auc:0.93368	valid-auc:0.84415
# [150]	train-auc:0.93410	valid-auc:0.84415
# [151]	train-auc:0.93449	valid-auc:0.84415
# [152]	train-auc:0.93512	valid-auc:0.84413
# [153]	train-auc:0.93559	valid-auc:0.84427
# [154]	train-auc:0.93582	valid-auc:0.84411
# [155]	train-auc:0.93617	valid-auc:0.84418
# [156]	train-auc:0.93665	valid-auc:0.84419
# [157]	train-auc:0.93693	valid-auc:0.84415
# [158]	train-auc:0.93719	valid-auc:0.84413
# [159]	train-auc:0.93742	valid-auc:0.84419
# [160]	train-auc:0.93790	valid-auc:0.84427
# [161]	train-auc:0.93795	valid-auc:0.84432
# [162]	train-auc:0.93835	valid-auc:0.84436
# [163]	train-auc:0.93886	valid-auc:0.84447
# [164]	train-auc:0.93929	valid-auc:0.84443
# [165]	train-auc:0.93980	valid-auc:0.84438
# [166]	train-auc:0.94034	valid-auc:0.84441
# [167]	train-auc:0.94083	valid-auc:0.84443
# [168]	train-auc:0.94130	valid-auc:0.84454
# [169]	train-auc:0.94162	valid-auc:0.84460
# [170]	train-auc:0.94186	valid-auc:0.84471
# [171]	train-auc:0.94202	valid-auc:0.84466
# [172]	train-auc:0.94238	valid-auc:0.84464
# [173]	train-auc:0.94289	valid-auc:0.84475
# [174]	train-auc:0.94332	valid-auc:0.84472
# [175]	train-auc:0.94345	valid-auc:0.84477
# [176]	train-auc:0.94380	valid-auc:0.84457
# [177]	train-auc:0.94417	valid-auc:0.84453
# [178]	train-auc:0.94441	valid-auc:0.84451
# [179]	train-auc:0.94456	valid-auc:0.84462
# [180]	train-auc:0.94488	valid-auc:0.84464
# [181]	train-auc:0.94529	valid-auc:0.84457
# [182]	train-auc:0.94555	valid-auc:0.84459
# [183]	train-auc:0.94585	valid-auc:0.84472
# [184]	train-auc:0.94605	valid-auc:0.84472
# [185]	train-auc:0.94628	valid-auc:0.84470
# [186]	train-auc:0.94653	valid-auc:0.84478
# [187]	train-auc:0.94692	valid-auc:0.84470
# [188]	train-auc:0.94724	valid-auc:0.84470
# [189]	train-auc:0.94754	valid-auc:0.84469
# [190]	train-auc:0.94775	valid-auc:0.84470
# [191]	train-auc:0.94822	valid-auc:0.84469
# [192]	train-auc:0.94827	valid-auc:0.84473
# [193]	train-auc:0.94872	valid-auc:0.84476
# [194]	train-auc:0.94888	valid-auc:0.84479
# [195]	train-auc:0.94898	valid-auc:0.84482
# [196]	train-auc:0.94911	valid-auc:0.84494
# [197]	train-auc:0.94958	valid-auc:0.84485
# [198]	train-auc:0.94998	valid-auc:0.84492
# [199]	train-auc:0.95020	valid-auc:0.84493
# [200]	train-auc:0.95049	valid-auc:0.84509
# [201]	train-auc:0.95071	valid-auc:0.84520
# [202]	train-auc:0.95113	valid-auc:0.84506
# [203]	train-auc:0.95129	valid-auc:0.84514
# [204]	train-auc:0.95166	valid-auc:0.84515
# [205]	train-auc:0.95193	valid-auc:0.84533
# [206]	train-auc:0.95225	valid-auc:0.84537
# [207]	train-auc:0.95253	valid-auc:0.84541
# [208]	train-auc:0.95293	valid-auc:0.84544
# [209]	train-auc:0.95339	valid-auc:0.84536
# [210]	train-auc:0.95356	valid-auc:0.84549
# [211]	train-auc:0.95383	valid-auc:0.84545
# [212]	train-auc:0.95418	valid-auc:0.84555
# [213]	train-auc:0.95452	valid-auc:0.84555
# [214]	train-auc:0.95471	valid-auc:0.84547
# [215]	train-auc:0.95506	valid-auc:0.84551
# [216]	train-auc:0.95531	valid-auc:0.84559
# [217]	train-auc:0.95550	valid-auc:0.84567
# [218]	train-auc:0.95583	valid-auc:0.84581
# [219]	train-auc:0.95603	valid-auc:0.84589
# [220]	train-auc:0.95639	valid-auc:0.84592
# [221]	train-auc:0.95654	valid-auc:0.84585
# [222]	train-auc:0.95693	valid-auc:0.84568
# [223]	train-auc:0.95723	valid-auc:0.84570
# [224]	train-auc:0.95748	valid-auc:0.84571
# [225]	train-auc:0.95765	valid-auc:0.84577
# [226]	train-auc:0.95780	valid-auc:0.84570
# [227]	train-auc:0.95795	valid-auc:0.84574
# [228]	train-auc:0.95834	valid-auc:0.84582
# [229]	train-auc:0.95849	valid-auc:0.84589
# [230]	train-auc:0.95866	valid-auc:0.84590
# [231]	train-auc:0.95889	valid-auc:0.84595
# [232]	train-auc:0.95913	valid-auc:0.84590
# [233]	train-auc:0.95937	valid-auc:0.84586
# [234]	train-auc:0.95960	valid-auc:0.84588
# [235]	train-auc:0.95988	valid-auc:0.84586
# [236]	train-auc:0.96016	valid-auc:0.84589
# [237]	train-auc:0.96039	valid-auc:0.84598
# [238]	train-auc:0.96064	valid-auc:0.84597
# [239]	train-auc:0.96100	valid-auc:0.84594
# [240]	train-auc:0.96122	valid-auc:0.84599
# [241]	train-auc:0.96151	valid-auc:0.84587
# [242]	train-auc:0.96171	valid-auc:0.84593
# [243]	train-auc:0.96186	valid-auc:0.84598
# [244]	train-auc:0.96204	valid-auc:0.84626
# [245]	train-auc:0.96226	valid-auc:0.84638
# [246]	train-auc:0.96258	valid-auc:0.84662
# [247]	train-auc:0.96287	valid-auc:0.84667
# [248]	train-auc:0.96322	valid-auc:0.84646
# [249]	train-auc:0.96342	valid-auc:0.84648
# [250]	train-auc:0.96373	valid-auc:0.84650
# [251]	train-auc:0.96390	valid-auc:0.84646
# [252]	train-auc:0.96402	valid-auc:0.84649
# [253]	train-auc:0.96418	valid-auc:0.84640
# [254]	train-auc:0.96449	valid-auc:0.84639
# [255]	train-auc:0.96470	valid-auc:0.84650
# [256]	train-auc:0.96497	valid-auc:0.84659
# [257]	train-auc:0.96517	valid-auc:0.84665
# [258]	train-auc:0.96547	valid-auc:0.84657
# [259]	train-auc:0.96559	valid-auc:0.84654
# [260]	train-auc:0.96591	valid-auc:0.84667
# [261]	train-auc:0.96604	valid-auc:0.84666
# [262]	train-auc:0.96612	valid-auc:0.84654
# [263]	train-auc:0.96628	valid-auc:0.84657
# [264]	train-auc:0.96652	valid-auc:0.84667
# [265]	train-auc:0.96677	valid-auc:0.84666
# [266]	train-auc:0.96705	valid-auc:0.84655
# [267]	train-auc:0.96724	valid-auc:0.84654
# Stopping. Best iteration:
# [247]	train-auc:0.96287	valid-auc:0.84667
#
# fit severe_toxic
# [0]	train-auc:0.86061	valid-auc:0.82963
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.86748	valid-auc:0.83353
# [2]	train-auc:0.89354	valid-auc:0.86525
# [3]	train-auc:0.90238	valid-auc:0.87199
# [4]	train-auc:0.92054	valid-auc:0.88960
# [5]	train-auc:0.92206	valid-auc:0.88981
# [6]	train-auc:0.92404	valid-auc:0.89028
# [7]	train-auc:0.92516	valid-auc:0.89072
# [8]	train-auc:0.92653	valid-auc:0.89135
# [9]	train-auc:0.92780	valid-auc:0.89219
# [10]	train-auc:0.93242	valid-auc:0.89575
# [11]	train-auc:0.93279	valid-auc:0.89664
# [12]	train-auc:0.93757	valid-auc:0.90409
# [13]	train-auc:0.94278	valid-auc:0.91130
# [14]	train-auc:0.94342	valid-auc:0.91092
# [15]	train-auc:0.94425	valid-auc:0.91021
# [16]	train-auc:0.94605	valid-auc:0.91303
# [17]	train-auc:0.94893	valid-auc:0.91569
# [18]	train-auc:0.94991	valid-auc:0.91607
# [19]	train-auc:0.94994	valid-auc:0.91564
# [20]	train-auc:0.95090	valid-auc:0.91577
# [21]	train-auc:0.95167	valid-auc:0.91522
# [22]	train-auc:0.95243	valid-auc:0.91431
# [23]	train-auc:0.95374	valid-auc:0.91667
# [24]	train-auc:0.95615	valid-auc:0.91607
# [25]	train-auc:0.95819	valid-auc:0.91953
# [26]	train-auc:0.95955	valid-auc:0.91964
# [27]	train-auc:0.96115	valid-auc:0.92104
# [28]	train-auc:0.96209	valid-auc:0.92147
# [29]	train-auc:0.96379	valid-auc:0.92149
# [30]	train-auc:0.96475	valid-auc:0.92270
# [31]	train-auc:0.96547	valid-auc:0.92247
# [32]	train-auc:0.96638	valid-auc:0.92310
# [33]	train-auc:0.96714	valid-auc:0.92312
# [34]	train-auc:0.96811	valid-auc:0.92344
# [35]	train-auc:0.96875	valid-auc:0.92303
# [36]	train-auc:0.96908	valid-auc:0.92293
# [37]	train-auc:0.97009	valid-auc:0.92256
# [38]	train-auc:0.97081	valid-auc:0.92405
# [39]	train-auc:0.97163	valid-auc:0.92373
# [40]	train-auc:0.97294	valid-auc:0.92534
# [41]	train-auc:0.97337	valid-auc:0.92570
# [42]	train-auc:0.97435	valid-auc:0.92613
# [43]	train-auc:0.97507	valid-auc:0.92649
# [44]	train-auc:0.97571	valid-auc:0.92744
# [45]	train-auc:0.97676	valid-auc:0.92719
# [46]	train-auc:0.97764	valid-auc:0.92977
# [47]	train-auc:0.97836	valid-auc:0.93003
# [48]	train-auc:0.97887	valid-auc:0.92964
# [49]	train-auc:0.97945	valid-auc:0.93043
# [50]	train-auc:0.97997	valid-auc:0.92979
# [51]	train-auc:0.98003	valid-auc:0.92881
# [52]	train-auc:0.98077	valid-auc:0.92914
# [53]	train-auc:0.98199	valid-auc:0.93023
# [54]	train-auc:0.98259	valid-auc:0.93064
# [55]	train-auc:0.98295	valid-auc:0.93068
# [56]	train-auc:0.98365	valid-auc:0.93110
# [57]	train-auc:0.98446	valid-auc:0.93103
# [58]	train-auc:0.98489	valid-auc:0.93027
# [59]	train-auc:0.98527	valid-auc:0.93129
# [60]	train-auc:0.98588	valid-auc:0.93157
# [61]	train-auc:0.98640	valid-auc:0.93200
# [62]	train-auc:0.98663	valid-auc:0.93222
# [63]	train-auc:0.98703	valid-auc:0.93214
# [64]	train-auc:0.98771	valid-auc:0.93181
# [65]	train-auc:0.98820	valid-auc:0.93297
# [66]	train-auc:0.98862	valid-auc:0.93290
# [67]	train-auc:0.98895	valid-auc:0.93289
# [68]	train-auc:0.98938	valid-auc:0.93234
# [69]	train-auc:0.98970	valid-auc:0.93329
# [70]	train-auc:0.99003	valid-auc:0.93393
# [71]	train-auc:0.99028	valid-auc:0.93400
# [72]	train-auc:0.99068	valid-auc:0.93415
# [73]	train-auc:0.99106	valid-auc:0.93466
# [74]	train-auc:0.99128	valid-auc:0.93518
# [75]	train-auc:0.99167	valid-auc:0.93580
# [76]	train-auc:0.99191	valid-auc:0.93653
# [77]	train-auc:0.99225	valid-auc:0.93614
# [78]	train-auc:0.99243	valid-auc:0.93638
# [79]	train-auc:0.99264	valid-auc:0.93626
# [80]	train-auc:0.99282	valid-auc:0.93606
# [81]	train-auc:0.99315	valid-auc:0.93676
# [82]	train-auc:0.99333	valid-auc:0.93721
# [83]	train-auc:0.99350	valid-auc:0.93727
# [84]	train-auc:0.99368	valid-auc:0.93717
# [85]	train-auc:0.99383	valid-auc:0.93739
# [86]	train-auc:0.99403	valid-auc:0.93757
# [87]	train-auc:0.99406	valid-auc:0.93778
# [88]	train-auc:0.99422	valid-auc:0.93714
# [89]	train-auc:0.99443	valid-auc:0.93756
# [90]	train-auc:0.99474	valid-auc:0.93792
# [91]	train-auc:0.99495	valid-auc:0.93769
# [92]	train-auc:0.99503	valid-auc:0.93778
# [93]	train-auc:0.99533	valid-auc:0.93720
# [94]	train-auc:0.99556	valid-auc:0.93723
# [95]	train-auc:0.99564	valid-auc:0.93735
# [96]	train-auc:0.99570	valid-auc:0.93731
# [97]	train-auc:0.99585	valid-auc:0.93730
# [98]	train-auc:0.99599	valid-auc:0.93761
# [99]	train-auc:0.99608	valid-auc:0.93694
# [100]	train-auc:0.99631	valid-auc:0.93729
# [101]	train-auc:0.99644	valid-auc:0.93727
# [102]	train-auc:0.99655	valid-auc:0.93737
# [103]	train-auc:0.99667	valid-auc:0.93723
# [104]	train-auc:0.99676	valid-auc:0.93703
# [105]	train-auc:0.99692	valid-auc:0.93725
# [106]	train-auc:0.99701	valid-auc:0.93733
# [107]	train-auc:0.99717	valid-auc:0.93723
# [108]	train-auc:0.99724	valid-auc:0.93740
# [109]	train-auc:0.99731	valid-auc:0.93746
# [110]	train-auc:0.99738	valid-auc:0.93746
# Stopping. Best iteration:
# [90]	train-auc:0.99474	valid-auc:0.93792
#
# fit obscene
# [0]	train-auc:0.81388	valid-auc:0.80743
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.83543	valid-auc:0.82770
# [2]	train-auc:0.84261	valid-auc:0.83348
# [3]	train-auc:0.84698	valid-auc:0.83865
# [4]	train-auc:0.85168	valid-auc:0.84024
# [5]	train-auc:0.85398	valid-auc:0.84140
# [6]	train-auc:0.85449	valid-auc:0.84181
# [7]	train-auc:0.85572	valid-auc:0.84276
# [8]	train-auc:0.85944	valid-auc:0.84526
# [9]	train-auc:0.86047	valid-auc:0.84620
# [10]	train-auc:0.86273	valid-auc:0.84693
# [11]	train-auc:0.86461	valid-auc:0.84869
# [12]	train-auc:0.86594	valid-auc:0.84888
# [13]	train-auc:0.86808	valid-auc:0.85109
# [14]	train-auc:0.86881	valid-auc:0.85138
# [15]	train-auc:0.87016	valid-auc:0.85238
# [16]	train-auc:0.87224	valid-auc:0.85353
# [17]	train-auc:0.87355	valid-auc:0.85430
# [18]	train-auc:0.87466	valid-auc:0.85477
# [19]	train-auc:0.87496	valid-auc:0.85492
# [20]	train-auc:0.87635	valid-auc:0.85531
# [21]	train-auc:0.87754	valid-auc:0.85544
# [22]	train-auc:0.87891	valid-auc:0.85609
# [23]	train-auc:0.88053	valid-auc:0.85628
# [24]	train-auc:0.88216	valid-auc:0.85758
# [25]	train-auc:0.88394	valid-auc:0.85852
# [26]	train-auc:0.88513	valid-auc:0.85957
# [27]	train-auc:0.88675	valid-auc:0.85996
# [28]	train-auc:0.88857	valid-auc:0.86069
# [29]	train-auc:0.88988	valid-auc:0.86094
# [30]	train-auc:0.89123	valid-auc:0.86132
# [31]	train-auc:0.89254	valid-auc:0.86146
# [32]	train-auc:0.89375	valid-auc:0.86211
# [33]	train-auc:0.89495	valid-auc:0.86308
# [34]	train-auc:0.89629	valid-auc:0.86379
# [35]	train-auc:0.89712	valid-auc:0.86419
# [36]	train-auc:0.89865	valid-auc:0.86441
# [37]	train-auc:0.89992	valid-auc:0.86527
# [38]	train-auc:0.90115	valid-auc:0.86580
# [39]	train-auc:0.90252	valid-auc:0.86660
# [40]	train-auc:0.90391	valid-auc:0.86749
# [41]	train-auc:0.90557	valid-auc:0.86824
# [42]	train-auc:0.90690	valid-auc:0.86883
# [43]	train-auc:0.90801	valid-auc:0.86919
# [44]	train-auc:0.90903	valid-auc:0.86938
# [45]	train-auc:0.91021	valid-auc:0.86958
# [46]	train-auc:0.91122	valid-auc:0.86992
# [47]	train-auc:0.91241	valid-auc:0.87023
# [48]	train-auc:0.91362	valid-auc:0.87073
# [49]	train-auc:0.91475	valid-auc:0.87126
# [50]	train-auc:0.91583	valid-auc:0.87106
# [51]	train-auc:0.91658	valid-auc:0.87158
# [52]	train-auc:0.91752	valid-auc:0.87203
# [53]	train-auc:0.91848	valid-auc:0.87238
# [54]	train-auc:0.91938	valid-auc:0.87267
# [55]	train-auc:0.92042	valid-auc:0.87304
# [56]	train-auc:0.92119	valid-auc:0.87333
# [57]	train-auc:0.92229	valid-auc:0.87399
# [58]	train-auc:0.92332	valid-auc:0.87420
# [59]	train-auc:0.92420	valid-auc:0.87447
# [60]	train-auc:0.92529	valid-auc:0.87507
# [61]	train-auc:0.92599	valid-auc:0.87545
# [62]	train-auc:0.92650	valid-auc:0.87589
# [63]	train-auc:0.92765	valid-auc:0.87642
# [64]	train-auc:0.92819	valid-auc:0.87662
# [65]	train-auc:0.92881	valid-auc:0.87663
# [66]	train-auc:0.92970	valid-auc:0.87675
# [67]	train-auc:0.93042	valid-auc:0.87674
# [68]	train-auc:0.93142	valid-auc:0.87720
# [69]	train-auc:0.93202	valid-auc:0.87753
# [70]	train-auc:0.93276	valid-auc:0.87792
# [71]	train-auc:0.93363	valid-auc:0.87853
# [72]	train-auc:0.93436	valid-auc:0.87886
# [73]	train-auc:0.93530	valid-auc:0.87872
# [74]	train-auc:0.93595	valid-auc:0.87873
# [75]	train-auc:0.93668	valid-auc:0.87899
# [76]	train-auc:0.93727	valid-auc:0.87908
# [77]	train-auc:0.93785	valid-auc:0.87898
# [78]	train-auc:0.93841	valid-auc:0.87897
# [79]	train-auc:0.93892	valid-auc:0.87925
# [80]	train-auc:0.93964	valid-auc:0.87950
# [81]	train-auc:0.94040	valid-auc:0.87955
# [82]	train-auc:0.94078	valid-auc:0.87955
# [83]	train-auc:0.94144	valid-auc:0.87973
# [84]	train-auc:0.94194	valid-auc:0.87983
# [85]	train-auc:0.94242	valid-auc:0.87990
# [86]	train-auc:0.94305	valid-auc:0.87996
# [87]	train-auc:0.94347	valid-auc:0.87998
# [88]	train-auc:0.94376	valid-auc:0.88019
# [89]	train-auc:0.94427	valid-auc:0.88008
# [90]	train-auc:0.94475	valid-auc:0.88004
# [91]	train-auc:0.94532	valid-auc:0.88013
# [92]	train-auc:0.94599	valid-auc:0.88033
# [93]	train-auc:0.94639	valid-auc:0.88017
# [94]	train-auc:0.94696	valid-auc:0.88053
# [95]	train-auc:0.94741	valid-auc:0.88077
# [96]	train-auc:0.94785	valid-auc:0.88091
# [97]	train-auc:0.94813	valid-auc:0.88110
# [98]	train-auc:0.94839	valid-auc:0.88109
# [99]	train-auc:0.94903	valid-auc:0.88126
# [100]	train-auc:0.94960	valid-auc:0.88145
# [101]	train-auc:0.95007	valid-auc:0.88141
# [102]	train-auc:0.95052	valid-auc:0.88141
# [103]	train-auc:0.95122	valid-auc:0.88190
# [104]	train-auc:0.95170	valid-auc:0.88205
# [105]	train-auc:0.95215	valid-auc:0.88216
# [106]	train-auc:0.95265	valid-auc:0.88224
# [107]	train-auc:0.95309	valid-auc:0.88211
# [108]	train-auc:0.95354	valid-auc:0.88183
# [109]	train-auc:0.95432	valid-auc:0.88195
# [110]	train-auc:0.95476	valid-auc:0.88179
# [111]	train-auc:0.95502	valid-auc:0.88169
# [112]	train-auc:0.95531	valid-auc:0.88169
# [113]	train-auc:0.95595	valid-auc:0.88183
# [114]	train-auc:0.95631	valid-auc:0.88204
# [115]	train-auc:0.95684	valid-auc:0.88220
# [116]	train-auc:0.95721	valid-auc:0.88218
# [117]	train-auc:0.95741	valid-auc:0.88209
# [118]	train-auc:0.95784	valid-auc:0.88213
# [119]	train-auc:0.95804	valid-auc:0.88221
# [120]	train-auc:0.95839	valid-auc:0.88188
# [121]	train-auc:0.95868	valid-auc:0.88175
# [122]	train-auc:0.95905	valid-auc:0.88184
# [123]	train-auc:0.95952	valid-auc:0.88200
# [124]	train-auc:0.95970	valid-auc:0.88195
# [125]	train-auc:0.96004	valid-auc:0.88199
# [126]	train-auc:0.96024	valid-auc:0.88206
# Stopping. Best iteration:
# [106]	train-auc:0.95265	valid-auc:0.88224
#
# fit threat
# [0]	train-auc:0.72253	valid-auc:0.70223
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79626	valid-auc:0.75510
# [2]	train-auc:0.80725	valid-auc:0.76364
# [3]	train-auc:0.80765	valid-auc:0.76364
# [4]	train-auc:0.80761	valid-auc:0.76305
# [5]	train-auc:0.82122	valid-auc:0.76672
# [6]	train-auc:0.84438	valid-auc:0.80723
# [7]	train-auc:0.84349	valid-auc:0.80593
# [8]	train-auc:0.84276	valid-auc:0.80489
# [9]	train-auc:0.84254	valid-auc:0.80370
# [10]	train-auc:0.85200	valid-auc:0.81282
# [11]	train-auc:0.86578	valid-auc:0.83118
# [12]	train-auc:0.87140	valid-auc:0.83182
# [13]	train-auc:0.87766	valid-auc:0.83003
# [14]	train-auc:0.89062	valid-auc:0.83773
# [15]	train-auc:0.90266	valid-auc:0.86018
# [16]	train-auc:0.90392	valid-auc:0.86331
# [17]	train-auc:0.90976	valid-auc:0.86302
# [18]	train-auc:0.91314	valid-auc:0.86279
# [19]	train-auc:0.91485	valid-auc:0.86433
# [20]	train-auc:0.91681	valid-auc:0.87115
# [21]	train-auc:0.91908	valid-auc:0.87177
# [22]	train-auc:0.92299	valid-auc:0.87299
# [23]	train-auc:0.92565	valid-auc:0.88166
# [24]	train-auc:0.92803	valid-auc:0.88755
# [25]	train-auc:0.93153	valid-auc:0.88590
# [26]	train-auc:0.93601	valid-auc:0.88529
# [27]	train-auc:0.93834	valid-auc:0.88332
# [28]	train-auc:0.93954	valid-auc:0.88391
# [29]	train-auc:0.94037	valid-auc:0.88400
# [30]	train-auc:0.94492	valid-auc:0.89966
# [31]	train-auc:0.94604	valid-auc:0.89885
# [32]	train-auc:0.94627	valid-auc:0.90333
# [33]	train-auc:0.94814	valid-auc:0.90261
# [34]	train-auc:0.95086	valid-auc:0.90315
# [35]	train-auc:0.95193	valid-auc:0.90185
# [36]	train-auc:0.95459	valid-auc:0.90018
# [37]	train-auc:0.95583	valid-auc:0.90171
# [38]	train-auc:0.95697	valid-auc:0.90314
# [39]	train-auc:0.95860	valid-auc:0.90993
# [40]	train-auc:0.96083	valid-auc:0.90826
# [41]	train-auc:0.96364	valid-auc:0.91001
# [42]	train-auc:0.96495	valid-auc:0.91306
# [43]	train-auc:0.96591	valid-auc:0.91413
# [44]	train-auc:0.96724	valid-auc:0.91398
# [45]	train-auc:0.96788	valid-auc:0.91453
# [46]	train-auc:0.96901	valid-auc:0.91434
# [47]	train-auc:0.96997	valid-auc:0.91881
# [48]	train-auc:0.97298	valid-auc:0.91382
# [49]	train-auc:0.97300	valid-auc:0.91801
# [50]	train-auc:0.97352	valid-auc:0.91754
# [51]	train-auc:0.97463	valid-auc:0.92136
# [52]	train-auc:0.97563	valid-auc:0.92330
# [53]	train-auc:0.97994	valid-auc:0.92379
# [54]	train-auc:0.98172	valid-auc:0.92206
# [55]	train-auc:0.98270	valid-auc:0.92584
# [56]	train-auc:0.98327	valid-auc:0.92662
# [57]	train-auc:0.98557	valid-auc:0.92713
# [58]	train-auc:0.98643	valid-auc:0.92790
# [59]	train-auc:0.98646	valid-auc:0.92637
# [60]	train-auc:0.98692	valid-auc:0.92475
# [61]	train-auc:0.98925	valid-auc:0.92536
# [62]	train-auc:0.98929	valid-auc:0.92608
# [63]	train-auc:0.99003	valid-auc:0.92598
# [64]	train-auc:0.99015	valid-auc:0.92578
# [65]	train-auc:0.99106	valid-auc:0.92682
# [66]	train-auc:0.99200	valid-auc:0.92685
# [67]	train-auc:0.99275	valid-auc:0.92588
# [68]	train-auc:0.99343	valid-auc:0.92658
# [69]	train-auc:0.99388	valid-auc:0.92903
# [70]	train-auc:0.99469	valid-auc:0.92949
# [71]	train-auc:0.99488	valid-auc:0.92904
# [72]	train-auc:0.99508	valid-auc:0.92803
# [73]	train-auc:0.99531	valid-auc:0.92951
# [74]	train-auc:0.99548	valid-auc:0.92932
# [75]	train-auc:0.99581	valid-auc:0.93168
# [76]	train-auc:0.99616	valid-auc:0.93243
# [77]	train-auc:0.99673	valid-auc:0.93255
# [78]	train-auc:0.99730	valid-auc:0.93187
# [79]	train-auc:0.99737	valid-auc:0.93268
# [80]	train-auc:0.99747	valid-auc:0.93340
# [81]	train-auc:0.99784	valid-auc:0.93317
# [82]	train-auc:0.99788	valid-auc:0.93389
# [83]	train-auc:0.99801	valid-auc:0.93355
# [84]	train-auc:0.99820	valid-auc:0.93256
# [85]	train-auc:0.99829	valid-auc:0.93267
# [86]	train-auc:0.99837	valid-auc:0.93317
# [87]	train-auc:0.99852	valid-auc:0.93346
# [88]	train-auc:0.99864	valid-auc:0.93481
# [89]	train-auc:0.99880	valid-auc:0.93477
# [90]	train-auc:0.99888	valid-auc:0.93572
# [91]	train-auc:0.99890	valid-auc:0.93622
# [92]	train-auc:0.99894	valid-auc:0.93672
# [93]	train-auc:0.99896	valid-auc:0.93768
# [94]	train-auc:0.99905	valid-auc:0.93620
# [95]	train-auc:0.99914	valid-auc:0.93578
# [96]	train-auc:0.99915	valid-auc:0.93470
# [97]	train-auc:0.99926	valid-auc:0.93512
# [98]	train-auc:0.99927	valid-auc:0.93457
# [99]	train-auc:0.99931	valid-auc:0.93417
# [100]	train-auc:0.99930	valid-auc:0.93363
# [101]	train-auc:0.99938	valid-auc:0.93449
# [102]	train-auc:0.99945	valid-auc:0.93378
# [103]	train-auc:0.99947	valid-auc:0.93340
# [104]	train-auc:0.99950	valid-auc:0.93378
# [105]	train-auc:0.99960	valid-auc:0.93440
# [106]	train-auc:0.99964	valid-auc:0.93400
# [107]	train-auc:0.99968	valid-auc:0.93369
# [108]	train-auc:0.99971	valid-auc:0.93400
# [109]	train-auc:0.99973	valid-auc:0.93473
# [110]	train-auc:0.99973	valid-auc:0.93487
# [111]	train-auc:0.99975	valid-auc:0.93460
# [112]	train-auc:0.99978	valid-auc:0.93374
# [113]	train-auc:0.99982	valid-auc:0.93383
# Stopping. Best iteration:
# [93]	train-auc:0.99896	valid-auc:0.93768
#
# fit insult
# [0]	train-auc:0.80823	valid-auc:0.78397
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.83424	valid-auc:0.80875
# [2]	train-auc:0.84249	valid-auc:0.81852
# [3]	train-auc:0.84997	valid-auc:0.82468
# [4]	train-auc:0.85459	valid-auc:0.82813
# [5]	train-auc:0.85654	valid-auc:0.82878
# [6]	train-auc:0.85683	valid-auc:0.83004
# [7]	train-auc:0.85888	valid-auc:0.83035
# [8]	train-auc:0.86045	valid-auc:0.83208
# [9]	train-auc:0.86364	valid-auc:0.83548
# [10]	train-auc:0.86467	valid-auc:0.83659
# [11]	train-auc:0.86650	valid-auc:0.83739
# [12]	train-auc:0.86863	valid-auc:0.83926
# [13]	train-auc:0.87098	valid-auc:0.84182
# [14]	train-auc:0.87218	valid-auc:0.84270
# [15]	train-auc:0.87405	valid-auc:0.84379
# [16]	train-auc:0.87554	valid-auc:0.84370
# [17]	train-auc:0.87667	valid-auc:0.84412
# [18]	train-auc:0.87772	valid-auc:0.84435
# [19]	train-auc:0.87865	valid-auc:0.84520
# [20]	train-auc:0.87970	valid-auc:0.84563
# [21]	train-auc:0.88089	valid-auc:0.84674
# [22]	train-auc:0.88230	valid-auc:0.84711
# [23]	train-auc:0.88339	valid-auc:0.84774
# [24]	train-auc:0.88475	valid-auc:0.84827
# [25]	train-auc:0.88643	valid-auc:0.84904
# [26]	train-auc:0.88752	valid-auc:0.85035
# [27]	train-auc:0.88928	valid-auc:0.85147
# [28]	train-auc:0.89062	valid-auc:0.85240
# [29]	train-auc:0.89210	valid-auc:0.85243
# [30]	train-auc:0.89359	valid-auc:0.85290
# [31]	train-auc:0.89512	valid-auc:0.85347
# [32]	train-auc:0.89647	valid-auc:0.85416
# [33]	train-auc:0.89756	valid-auc:0.85488
# [34]	train-auc:0.89916	valid-auc:0.85554
# [35]	train-auc:0.90044	valid-auc:0.85632
# [36]	train-auc:0.90177	valid-auc:0.85693
# [37]	train-auc:0.90295	valid-auc:0.85773
# [38]	train-auc:0.90443	valid-auc:0.85839
# [39]	train-auc:0.90555	valid-auc:0.85901
# [40]	train-auc:0.90670	valid-auc:0.85934
# [41]	train-auc:0.90782	valid-auc:0.85945
# [42]	train-auc:0.90891	valid-auc:0.86029
# [43]	train-auc:0.91002	valid-auc:0.86082
# [44]	train-auc:0.91116	valid-auc:0.86118
# [45]	train-auc:0.91215	valid-auc:0.86136
# [46]	train-auc:0.91354	valid-auc:0.86171
# [47]	train-auc:0.91458	valid-auc:0.86180
# [48]	train-auc:0.91573	valid-auc:0.86237
# [49]	train-auc:0.91699	valid-auc:0.86314
# [50]	train-auc:0.91796	valid-auc:0.86352
# [51]	train-auc:0.91925	valid-auc:0.86396
# [52]	train-auc:0.92030	valid-auc:0.86469
# [53]	train-auc:0.92121	valid-auc:0.86494
# [54]	train-auc:0.92193	valid-auc:0.86484
# [55]	train-auc:0.92299	valid-auc:0.86520
# [56]	train-auc:0.92370	valid-auc:0.86526
# [57]	train-auc:0.92507	valid-auc:0.86559
# [58]	train-auc:0.92629	valid-auc:0.86623
# [59]	train-auc:0.92726	valid-auc:0.86656
# [60]	train-auc:0.92848	valid-auc:0.86709
# [61]	train-auc:0.92936	valid-auc:0.86726
# [62]	train-auc:0.93002	valid-auc:0.86759
# [63]	train-auc:0.93041	valid-auc:0.86801
# [64]	train-auc:0.93097	valid-auc:0.86804
# [65]	train-auc:0.93181	valid-auc:0.86840
# [66]	train-auc:0.93243	valid-auc:0.86869
# [67]	train-auc:0.93310	valid-auc:0.86903
# [68]	train-auc:0.93385	valid-auc:0.86938
# [69]	train-auc:0.93467	valid-auc:0.86967
# [70]	train-auc:0.93511	valid-auc:0.86968
# [71]	train-auc:0.93550	valid-auc:0.86960
# [72]	train-auc:0.93611	valid-auc:0.86987
# [73]	train-auc:0.93652	valid-auc:0.86991
# [74]	train-auc:0.93722	valid-auc:0.87027
# [75]	train-auc:0.93802	valid-auc:0.87022
# [76]	train-auc:0.93843	valid-auc:0.87062
# [77]	train-auc:0.93908	valid-auc:0.87100
# [78]	train-auc:0.93974	valid-auc:0.87134
# [79]	train-auc:0.94015	valid-auc:0.87143
# [80]	train-auc:0.94042	valid-auc:0.87164
# [81]	train-auc:0.94110	valid-auc:0.87185
# [82]	train-auc:0.94157	valid-auc:0.87182
# [83]	train-auc:0.94228	valid-auc:0.87176
# [84]	train-auc:0.94285	valid-auc:0.87185
# [85]	train-auc:0.94388	valid-auc:0.87182
# [86]	train-auc:0.94463	valid-auc:0.87186
# [87]	train-auc:0.94513	valid-auc:0.87208
# [88]	train-auc:0.94537	valid-auc:0.87211
# [89]	train-auc:0.94595	valid-auc:0.87233
# [90]	train-auc:0.94638	valid-auc:0.87240
# [91]	train-auc:0.94700	valid-auc:0.87250
# [92]	train-auc:0.94766	valid-auc:0.87289
# [93]	train-auc:0.94811	valid-auc:0.87284
# [94]	train-auc:0.94878	valid-auc:0.87294
# [95]	train-auc:0.94943	valid-auc:0.87293
# [96]	train-auc:0.95012	valid-auc:0.87304
# [97]	train-auc:0.95056	valid-auc:0.87325
# [98]	train-auc:0.95113	valid-auc:0.87343
# [99]	train-auc:0.95173	valid-auc:0.87383
# [100]	train-auc:0.95200	valid-auc:0.87397
# [101]	train-auc:0.95274	valid-auc:0.87415
# [102]	train-auc:0.95287	valid-auc:0.87425
# [103]	train-auc:0.95327	valid-auc:0.87450
# [104]	train-auc:0.95374	valid-auc:0.87473
# [105]	train-auc:0.95410	valid-auc:0.87486
# [106]	train-auc:0.95452	valid-auc:0.87505
# [107]	train-auc:0.95495	valid-auc:0.87486
# [108]	train-auc:0.95560	valid-auc:0.87491
# [109]	train-auc:0.95597	valid-auc:0.87516
# [110]	train-auc:0.95646	valid-auc:0.87528
# [111]	train-auc:0.95692	valid-auc:0.87527
# [112]	train-auc:0.95752	valid-auc:0.87540
# [113]	train-auc:0.95780	valid-auc:0.87557
# [114]	train-auc:0.95821	valid-auc:0.87554
# [115]	train-auc:0.95861	valid-auc:0.87567
# [116]	train-auc:0.95915	valid-auc:0.87596
# [117]	train-auc:0.95939	valid-auc:0.87595
# [118]	train-auc:0.95995	valid-auc:0.87618
# [119]	train-auc:0.96021	valid-auc:0.87637
# [120]	train-auc:0.96057	valid-auc:0.87645
# [121]	train-auc:0.96085	valid-auc:0.87623
# [122]	train-auc:0.96149	valid-auc:0.87636
# [123]	train-auc:0.96210	valid-auc:0.87631
# [124]	train-auc:0.96240	valid-auc:0.87606
# [125]	train-auc:0.96280	valid-auc:0.87598
# [126]	train-auc:0.96313	valid-auc:0.87590
# [127]	train-auc:0.96373	valid-auc:0.87594
# [128]	train-auc:0.96397	valid-auc:0.87577
# [129]	train-auc:0.96442	valid-auc:0.87582
# [130]	train-auc:0.96483	valid-auc:0.87592
# [131]	train-auc:0.96537	valid-auc:0.87590
# [132]	train-auc:0.96548	valid-auc:0.87594
# [133]	train-auc:0.96579	valid-auc:0.87588
# [134]	train-auc:0.96612	valid-auc:0.87595
# [135]	train-auc:0.96650	valid-auc:0.87617
# [136]	train-auc:0.96697	valid-auc:0.87623
# [137]	train-auc:0.96715	valid-auc:0.87618
# [138]	train-auc:0.96743	valid-auc:0.87632
# [139]	train-auc:0.96780	valid-auc:0.87629
# [140]	train-auc:0.96796	valid-auc:0.87621
# Stopping. Best iteration:
# [120]	train-auc:0.96057	valid-auc:0.87645
#
# fit identity_hate
# [0]	train-auc:0.76725	valid-auc:0.72898
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.80231	valid-auc:0.75969
# [2]	train-auc:0.81837	valid-auc:0.76947
# [3]	train-auc:0.82166	valid-auc:0.76996
# [4]	train-auc:0.82647	valid-auc:0.77289
# [5]	train-auc:0.82876	valid-auc:0.77454
# [6]	train-auc:0.82906	valid-auc:0.77335
# [7]	train-auc:0.82970	valid-auc:0.77266
# [8]	train-auc:0.83369	valid-auc:0.77467
# [9]	train-auc:0.83457	valid-auc:0.77613
# [10]	train-auc:0.84791	valid-auc:0.78585
# [11]	train-auc:0.85170	valid-auc:0.78925
# [12]	train-auc:0.85482	valid-auc:0.79432
# [13]	train-auc:0.85864	valid-auc:0.79876
# [14]	train-auc:0.85992	valid-auc:0.80090
# [15]	train-auc:0.86551	valid-auc:0.80253
# [16]	train-auc:0.86888	valid-auc:0.80782
# [17]	train-auc:0.87239	valid-auc:0.80703
# [18]	train-auc:0.87543	valid-auc:0.80949
# [19]	train-auc:0.87750	valid-auc:0.81051
# [20]	train-auc:0.87870	valid-auc:0.80957
# [21]	train-auc:0.88037	valid-auc:0.80897
# [22]	train-auc:0.88119	valid-auc:0.80804
# [23]	train-auc:0.88292	valid-auc:0.80927
# [24]	train-auc:0.88559	valid-auc:0.81046
# [25]	train-auc:0.88967	valid-auc:0.81090
# [26]	train-auc:0.89264	valid-auc:0.81346
# [27]	train-auc:0.89406	valid-auc:0.81594
# [28]	train-auc:0.89740	valid-auc:0.81742
# [29]	train-auc:0.89842	valid-auc:0.81780
# [30]	train-auc:0.90146	valid-auc:0.81991
# [31]	train-auc:0.90328	valid-auc:0.81920
# [32]	train-auc:0.90582	valid-auc:0.81767
# [33]	train-auc:0.90928	valid-auc:0.81746
# [34]	train-auc:0.91200	valid-auc:0.81750
# [35]	train-auc:0.91643	valid-auc:0.81881
# [36]	train-auc:0.91885	valid-auc:0.82090
# [37]	train-auc:0.92121	valid-auc:0.82324
# [38]	train-auc:0.92278	valid-auc:0.82239
# [39]	train-auc:0.92677	valid-auc:0.82341
# [40]	train-auc:0.92827	valid-auc:0.82451
# [41]	train-auc:0.92980	valid-auc:0.82451
# [42]	train-auc:0.93201	valid-auc:0.82805
# [43]	train-auc:0.93478	valid-auc:0.82912
# [44]	train-auc:0.93708	valid-auc:0.82971
# [45]	train-auc:0.93832	valid-auc:0.82944
# [46]	train-auc:0.94103	valid-auc:0.82816
# [47]	train-auc:0.94367	valid-auc:0.83032
# [48]	train-auc:0.94617	valid-auc:0.82974
# [49]	train-auc:0.94834	valid-auc:0.83165
# [50]	train-auc:0.95031	valid-auc:0.83211
# [51]	train-auc:0.95230	valid-auc:0.83274
# [52]	train-auc:0.95386	valid-auc:0.83244
# [53]	train-auc:0.95544	valid-auc:0.83396
# [54]	train-auc:0.95800	valid-auc:0.83497
# [55]	train-auc:0.95922	valid-auc:0.83656
# [56]	train-auc:0.96061	valid-auc:0.83786
# [57]	train-auc:0.96224	valid-auc:0.83881
# [58]	train-auc:0.96362	valid-auc:0.83973
# [59]	train-auc:0.96521	valid-auc:0.84199
# [60]	train-auc:0.96714	valid-auc:0.84254
# [61]	train-auc:0.96825	valid-auc:0.84370
# [62]	train-auc:0.96944	valid-auc:0.84466
# [63]	train-auc:0.97057	valid-auc:0.84501
# [64]	train-auc:0.97173	valid-auc:0.84574
# [65]	train-auc:0.97273	valid-auc:0.84668
# [66]	train-auc:0.97388	valid-auc:0.84519
# [67]	train-auc:0.97536	valid-auc:0.84534
# [68]	train-auc:0.97666	valid-auc:0.84609
# [69]	train-auc:0.97776	valid-auc:0.84424
# [70]	train-auc:0.97865	valid-auc:0.84396
# [71]	train-auc:0.97910	valid-auc:0.84420
# [72]	train-auc:0.98045	valid-auc:0.84541
# [73]	train-auc:0.98153	valid-auc:0.84543
# [74]	train-auc:0.98184	valid-auc:0.84554
# [75]	train-auc:0.98239	valid-auc:0.84523
# [76]	train-auc:0.98290	valid-auc:0.84590
# [77]	train-auc:0.98351	valid-auc:0.84545
# [78]	train-auc:0.98418	valid-auc:0.84417
# [79]	train-auc:0.98483	valid-auc:0.84386
# [80]	train-auc:0.98535	valid-auc:0.84433
# [81]	train-auc:0.98572	valid-auc:0.84434
# [82]	train-auc:0.98645	valid-auc:0.84438
# [83]	train-auc:0.98692	valid-auc:0.84455
# [84]	train-auc:0.98733	valid-auc:0.84312
# [85]	train-auc:0.98772	valid-auc:0.84500
# Stopping. Best iteration:
# [65]	train-auc:0.97273	valid-auc:0.84668

# %%
submission = pd.concat([submid, pd.DataFrame(preds, columns = col)], axis=1)
submission.to_csv('sample_submission_google_xgb.csv', index=False)
