# %%
import numpy as np
import pandas as pd
import re, string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC
import xgboost as xgb
import gc
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy
import multiprocessing

# %%
dtypes = {
    'comment_text'   : np.unicode ,
    'toxic':         np.int16, 
    'severe_toxic': np.int16,
    'obscene': np.int16,
    'threat': np.int16,
    'insult': np.int16,
    'identity_hate': np.int16
}

train = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/train.csv', dtype=dtypes, encoding='utf-8')
test = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/test.csv', dtype=dtypes, encoding='utf-8')

train.comment_text.fillna("unknown", inplace=True)
test.comment_text.fillna("unknown",  inplace=True)

subm = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/sample_submission.csv')    
submid = pd.DataFrame({'id': subm["id"].values.astype(str)}, dtype=np.str)

# %%
# Tokenization

re_tok = re.compile(u'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')

def tokenize(s):
    return re_tok.sub(r' \1 ', s).split()

# %% [markdown]
# ### FastText

# %%
train_mes, valid_mes, train_l, valid_l = train_test_split(train['comment_text'],
                                                          train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']],
                                                          test_size=0.2, random_state=42)
train_mes = pd.DataFrame(train_mes)
valid_mes = pd.DataFrame(valid_mes)

# %%
# load the FastText vectors in a dictionary:
from tqdm import tqdm

embeddings_index_FastText = {}
f = open('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Datasets/crawl-300d-2M.vec', encoding='utf-8')
for line in tqdm(f):
    values = line.split()
    word = values[0]
    try:
        coefs = np.asarray(values[1:], dtype='float32')
    except:
        continue
    embeddings_index_FastText[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index_FastText))
# Out:
# 1999996it [03:19, 10014.87it/s]
# Found 1999996 word vectors.

# %%
# Function to create a normalized vector for the whole sentence
def sent2vec(s, embeddings_index):
    words = str(s).lower()
    words = tokenize(words)
    words = [w for w in words if w.isalpha()]
    M = []
    for w in words:
        try:
            M.append(embeddings_index[w])
        except:
            continue
    M = np.array(M)
    v = M.sum(axis=0)
    if type(v) != np.ndarray:
        return np.zeros(300)
    return v / np.sqrt((v ** 2).sum())

# %%
gc.collect()

# Create sentence vectors using the above function for training and validation set
xtrain_FastText = [sent2vec(x, embeddings_index_FastText) for x in train_mes['comment_text']]
xvalid_FastText = [sent2vec(x, embeddings_index_FastText) for x in valid_mes['comment_text']]

xtrain_FastText = np.array(xtrain_FastText)
xvalid_FastText = np.array(xvalid_FastText)

print("xtrain_FastText.shape = ", xtrain_FastText.shape)
print("xvalid_FastText.shape = ", xvalid_FastText.shape)
 
# Generate Word vectors of test data
xtest_FastText = [sent2vec(x, embeddings_index_FastText) for x in test['comment_text']]
xtest_FastText = np.array(xtest_FastText)
# Out:
# xtrain_FastText.shape =  (127656, 300)
# xvalid_FastText.shape =  (31915, 300)

# %% [markdown]
# ### SGD Classifier

# %%
scores = []
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((valid_mes.shape[0], len(col))).astype(object)

for i, class_name in enumerate(col):
    print('fit '+ class_name)
    classifier = SGDClassifier(loss='log', max_iter=1000, epsilon=0.001, n_jobs=-1)

    cv_score = np.mean(cross_val_score(classifier, xtrain_FastText, train_l[class_name], cv=5, scoring='roc_auc'))
    scores.append(cv_score)
    print('CV score for class {} is {}'.format(class_name, cv_score))

    classifier.fit(xtrain_FastText, train_l[class_name])
    preds[:,i] = classifier.predict_proba(xvalid_FastText)[:,1]
    
print('Total CV score is {}'.format(np.mean(scores)))
# Out:
# fit toxic
# CV score for class toxic is 0.778880261178883
# fit severe_toxic
# CV score for class severe_toxic is 0.9014068553955387
# fit obscene
# CV score for class obscene is 0.818231838029696
# fit threat
# CV score for class threat is 0.8586549413107658
# fit insult
# CV score for class insult is 0.8165125034213844
# fit identity_hate
# CV score for class identity_hate is 0.8151732642551238
# Total CV score is 0.8314766105985653

# %%
testpreds_FastText = np.zeros((test.shape[0], len(col)))
for i, class_name in enumerate(col):
    print('fit '+ class_name)
    testpreds_FastText[:,i] = classifier.predict_proba(xtest_FastText)[:,1]
    
submission = pd.concat([submid, pd.DataFrame(testpreds_FastText, columns = col)], axis=1)
submission.to_csv('sample_submission_FastText_sgd.csv', index=False)
# Out:
# fit toxic
# fit severe_toxic
# fit obscene
# fit threat
# fit insult
# fit identity_hate

# %% [markdown]
# ### Logistic Regression Classifier

# %%
scores = []
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((valid_mes.shape[0], len(col))).astype(object)

for i, class_name in enumerate(col):
    print('fit '+ class_name)
    classifier = LogisticRegression(C=0.1, solver='sag')
#    classifier = SVC(C=1.0, probability=True)

    cv_score = np.mean(cross_val_score(classifier, xtrain_FastText, train_l[class_name], cv=5, scoring='roc_auc'))
    scores.append(cv_score)
    print('CV score for class {} is {}'.format(class_name, cv_score))

    classifier.fit(xtrain_FastText, train_l[class_name])
    preds[:,i] = classifier.predict_proba(xvalid_FastText)[:,1]
    
print('Total CV score is {}'.format(np.mean(scores)))
# Out:
# fit toxic
# CV score for class toxic is 0.7792949071732895
# fit severe_toxic
# CV score for class severe_toxic is 0.9015847215229795
# fit obscene
# CV score for class obscene is 0.8186233127456995
# fit threat
# CV score for class threat is 0.8587920060063053
# fit insult
# CV score for class insult is 0.8167887840205079
# fit identity_hate
# CV score for class identity_hate is 0.8153501588383577
# Total CV score is 0.8317389817178565

# %%
testpreds_FastText = np.zeros((test.shape[0], len(col)))
for i, class_name in enumerate(col):
    print('fit '+ class_name)
    testpreds_FastText[:,i] = classifier.predict_proba(xtest_FastText)[:,1]
    
submission = pd.concat([submid, pd.DataFrame(testpreds_FastText, columns = col)], axis=1)
submission.to_csv('sample_submission_FastText_logit.csv', index=False)
# Out:
# fit toxic
# fit severe_toxic
# fit obscene
# fit threat
# fit insult
# fit identity_hate

# %% [markdown]
# ### XGBoost Classifier

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=2017, num_rounds=500):
    param = {}
    param['objective'] = 'binary:logistic'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['eval_metric'] = 'auc'
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'valid') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    return model

# %%
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((test.shape[0], len(col)))

for i, j in enumerate(col):
    print('fit '+j)
    model = runXGB(xtrain_FastText, train_l[j], xvalid_FastText, valid_l[j])
    preds[:,i] = model.predict(xgb.DMatrix(xtest_FastText), ntree_limit = model.best_ntree_limit)
    gc.collect()
# Out:
# fit toxic
# [0]	train-auc:0.77959	valid-auc:0.76944
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79937	valid-auc:0.78615
# [2]	train-auc:0.80626	valid-auc:0.79430
# [3]	train-auc:0.81165	valid-auc:0.79850
# [4]	train-auc:0.81605	valid-auc:0.80091
# [5]	train-auc:0.81868	valid-auc:0.80310
# [6]	train-auc:0.82023	valid-auc:0.80477
# [7]	train-auc:0.82232	valid-auc:0.80581
# [8]	train-auc:0.82499	valid-auc:0.80657
# [9]	train-auc:0.82614	valid-auc:0.80772
# [10]	train-auc:0.82742	valid-auc:0.80840
# [11]	train-auc:0.82886	valid-auc:0.80893
# [12]	train-auc:0.83044	valid-auc:0.80936
# [13]	train-auc:0.83203	valid-auc:0.81109
# [14]	train-auc:0.83349	valid-auc:0.81186
# [15]	train-auc:0.83542	valid-auc:0.81312
# [16]	train-auc:0.83679	valid-auc:0.81397
# [17]	train-auc:0.83806	valid-auc:0.81423
# [18]	train-auc:0.83949	valid-auc:0.81507
# [19]	train-auc:0.84084	valid-auc:0.81635
# [20]	train-auc:0.84191	valid-auc:0.81658
# [21]	train-auc:0.84280	valid-auc:0.81688
# [22]	train-auc:0.84410	valid-auc:0.81766
# [23]	train-auc:0.84555	valid-auc:0.81825
# [24]	train-auc:0.84695	valid-auc:0.81863
# [25]	train-auc:0.84822	valid-auc:0.81970
# [26]	train-auc:0.84949	valid-auc:0.82008
# [27]	train-auc:0.85064	valid-auc:0.82058
# [28]	train-auc:0.85187	valid-auc:0.82134
# [29]	train-auc:0.85327	valid-auc:0.82185
# [30]	train-auc:0.85450	valid-auc:0.82256
# [31]	train-auc:0.85567	valid-auc:0.82347
# [32]	train-auc:0.85688	valid-auc:0.82346
# [33]	train-auc:0.85814	valid-auc:0.82438
# [34]	train-auc:0.85941	valid-auc:0.82501
# [35]	train-auc:0.86073	valid-auc:0.82592
# [36]	train-auc:0.86198	valid-auc:0.82655
# [37]	train-auc:0.86306	valid-auc:0.82726
# [38]	train-auc:0.86411	valid-auc:0.82806
# [39]	train-auc:0.86539	valid-auc:0.82876
# [40]	train-auc:0.86652	valid-auc:0.82936
# [41]	train-auc:0.86782	valid-auc:0.82991
# [42]	train-auc:0.86891	valid-auc:0.83005
# [43]	train-auc:0.87016	valid-auc:0.83085
# [44]	train-auc:0.87109	valid-auc:0.83138
# [45]	train-auc:0.87225	valid-auc:0.83189
# [46]	train-auc:0.87327	valid-auc:0.83233
# [47]	train-auc:0.87446	valid-auc:0.83245
# [48]	train-auc:0.87558	valid-auc:0.83288
# [49]	train-auc:0.87655	valid-auc:0.83322
# [50]	train-auc:0.87762	valid-auc:0.83374
# [51]	train-auc:0.87862	valid-auc:0.83405
# [52]	train-auc:0.87956	valid-auc:0.83466
# [53]	train-auc:0.88046	valid-auc:0.83509
# [54]	train-auc:0.88151	valid-auc:0.83550
# [55]	train-auc:0.88236	valid-auc:0.83570
# [56]	train-auc:0.88330	valid-auc:0.83633
# [57]	train-auc:0.88424	valid-auc:0.83668
# [58]	train-auc:0.88512	valid-auc:0.83714
# [59]	train-auc:0.88564	valid-auc:0.83724
# [60]	train-auc:0.88650	valid-auc:0.83760
# [61]	train-auc:0.88743	valid-auc:0.83803
# [62]	train-auc:0.88841	valid-auc:0.83827
# [63]	train-auc:0.88930	valid-auc:0.83880
# [64]	train-auc:0.88973	valid-auc:0.83893
# [65]	train-auc:0.89051	valid-auc:0.83900
# [66]	train-auc:0.89135	valid-auc:0.83914
# [67]	train-auc:0.89203	valid-auc:0.83930
# [68]	train-auc:0.89260	valid-auc:0.83962
# [69]	train-auc:0.89312	valid-auc:0.83984
# [70]	train-auc:0.89384	valid-auc:0.83997
# [71]	train-auc:0.89446	valid-auc:0.84021
# [72]	train-auc:0.89506	valid-auc:0.84033
# [73]	train-auc:0.89546	valid-auc:0.84040
# [74]	train-auc:0.89623	valid-auc:0.84062
# [75]	train-auc:0.89712	valid-auc:0.84088
# [76]	train-auc:0.89782	valid-auc:0.84103
# [77]	train-auc:0.89869	valid-auc:0.84124
# [78]	train-auc:0.89939	valid-auc:0.84140
# [79]	train-auc:0.90002	valid-auc:0.84155
# [80]	train-auc:0.90087	valid-auc:0.84167
# [81]	train-auc:0.90151	valid-auc:0.84199
# [82]	train-auc:0.90209	valid-auc:0.84219
# [83]	train-auc:0.90250	valid-auc:0.84236
# [84]	train-auc:0.90279	valid-auc:0.84244
# [85]	train-auc:0.90331	valid-auc:0.84253
# [86]	train-auc:0.90402	valid-auc:0.84267
# [87]	train-auc:0.90478	valid-auc:0.84277
# [88]	train-auc:0.90531	valid-auc:0.84294
# [89]	train-auc:0.90585	valid-auc:0.84325
# [90]	train-auc:0.90648	valid-auc:0.84348
# [91]	train-auc:0.90688	valid-auc:0.84349
# [92]	train-auc:0.90743	valid-auc:0.84388
# [93]	train-auc:0.90799	valid-auc:0.84404
# [94]	train-auc:0.90831	valid-auc:0.84423
# [95]	train-auc:0.90876	valid-auc:0.84433
# [96]	train-auc:0.90942	valid-auc:0.84438
# [97]	train-auc:0.91000	valid-auc:0.84442
# [98]	train-auc:0.91062	valid-auc:0.84448
# [99]	train-auc:0.91124	valid-auc:0.84464
# [100]	train-auc:0.91183	valid-auc:0.84475
# [101]	train-auc:0.91249	valid-auc:0.84482
# [102]	train-auc:0.91293	valid-auc:0.84495
# [103]	train-auc:0.91354	valid-auc:0.84511
# [104]	train-auc:0.91418	valid-auc:0.84538
# [105]	train-auc:0.91472	valid-auc:0.84547
# [106]	train-auc:0.91546	valid-auc:0.84557
# [107]	train-auc:0.91571	valid-auc:0.84564
# [108]	train-auc:0.91607	valid-auc:0.84571
# [109]	train-auc:0.91651	valid-auc:0.84584
# [110]	train-auc:0.91712	valid-auc:0.84603
# [111]	train-auc:0.91765	valid-auc:0.84594
# [112]	train-auc:0.91796	valid-auc:0.84581
# [113]	train-auc:0.91844	valid-auc:0.84575
# [114]	train-auc:0.91890	valid-auc:0.84589
# [115]	train-auc:0.91945	valid-auc:0.84584
# [116]	train-auc:0.91977	valid-auc:0.84587
# [117]	train-auc:0.92031	valid-auc:0.84581
# [118]	train-auc:0.92058	valid-auc:0.84592
# [119]	train-auc:0.92105	valid-auc:0.84597
# [120]	train-auc:0.92161	valid-auc:0.84613
# [121]	train-auc:0.92217	valid-auc:0.84618
# [122]	train-auc:0.92277	valid-auc:0.84633
# [123]	train-auc:0.92327	valid-auc:0.84655
# [124]	train-auc:0.92371	valid-auc:0.84670
# [125]	train-auc:0.92419	valid-auc:0.84688
# [126]	train-auc:0.92453	valid-auc:0.84678
# [127]	train-auc:0.92498	valid-auc:0.84671
# [128]	train-auc:0.92513	valid-auc:0.84665
# [129]	train-auc:0.92573	valid-auc:0.84684
# [130]	train-auc:0.92617	valid-auc:0.84687
# [131]	train-auc:0.92683	valid-auc:0.84701
# [132]	train-auc:0.92731	valid-auc:0.84700
# [133]	train-auc:0.92779	valid-auc:0.84720
# [134]	train-auc:0.92800	valid-auc:0.84728
# [135]	train-auc:0.92846	valid-auc:0.84725
# [136]	train-auc:0.92891	valid-auc:0.84730
# [137]	train-auc:0.92926	valid-auc:0.84738
# [138]	train-auc:0.92949	valid-auc:0.84718
# [139]	train-auc:0.92992	valid-auc:0.84734
# [140]	train-auc:0.93020	valid-auc:0.84741
# [141]	train-auc:0.93049	valid-auc:0.84753
# [142]	train-auc:0.93119	valid-auc:0.84765
# [143]	train-auc:0.93170	valid-auc:0.84766
# [144]	train-auc:0.93214	valid-auc:0.84781
# [145]	train-auc:0.93263	valid-auc:0.84779
# [146]	train-auc:0.93286	valid-auc:0.84786
# [147]	train-auc:0.93302	valid-auc:0.84789
# [148]	train-auc:0.93349	valid-auc:0.84794
# [149]	train-auc:0.93380	valid-auc:0.84799
# [150]	train-auc:0.93426	valid-auc:0.84804
# [151]	train-auc:0.93477	valid-auc:0.84819
# [152]	train-auc:0.93515	valid-auc:0.84817
# [153]	train-auc:0.93561	valid-auc:0.84811
# [154]	train-auc:0.93603	valid-auc:0.84804
# [155]	train-auc:0.93635	valid-auc:0.84809
# [156]	train-auc:0.93659	valid-auc:0.84804
# [157]	train-auc:0.93677	valid-auc:0.84810
# [158]	train-auc:0.93703	valid-auc:0.84830
# [159]	train-auc:0.93742	valid-auc:0.84824
# [160]	train-auc:0.93798	valid-auc:0.84832
# [161]	train-auc:0.93836	valid-auc:0.84849
# [162]	train-auc:0.93865	valid-auc:0.84856
# [163]	train-auc:0.93916	valid-auc:0.84865
# [164]	train-auc:0.93948	valid-auc:0.84865
# [165]	train-auc:0.93982	valid-auc:0.84876
# [166]	train-auc:0.94025	valid-auc:0.84876
# [167]	train-auc:0.94050	valid-auc:0.84882
# [168]	train-auc:0.94070	valid-auc:0.84882
# [169]	train-auc:0.94090	valid-auc:0.84886
# [170]	train-auc:0.94123	valid-auc:0.84889
# [171]	train-auc:0.94134	valid-auc:0.84889
# [172]	train-auc:0.94167	valid-auc:0.84901
# [173]	train-auc:0.94199	valid-auc:0.84902
# [174]	train-auc:0.94228	valid-auc:0.84910
# [175]	train-auc:0.94268	valid-auc:0.84912
# [176]	train-auc:0.94281	valid-auc:0.84917
# [177]	train-auc:0.94303	valid-auc:0.84918
# [178]	train-auc:0.94350	valid-auc:0.84916
# [179]	train-auc:0.94382	valid-auc:0.84916
# [180]	train-auc:0.94439	valid-auc:0.84915
# [181]	train-auc:0.94475	valid-auc:0.84928
# [182]	train-auc:0.94497	valid-auc:0.84933
# [183]	train-auc:0.94541	valid-auc:0.84948
# [184]	train-auc:0.94572	valid-auc:0.84949
# [185]	train-auc:0.94613	valid-auc:0.84953
# [186]	train-auc:0.94632	valid-auc:0.84961
# [187]	train-auc:0.94653	valid-auc:0.84964
# [188]	train-auc:0.94686	valid-auc:0.84968
# [189]	train-auc:0.94710	valid-auc:0.84969
# [190]	train-auc:0.94722	valid-auc:0.84968
# [191]	train-auc:0.94773	valid-auc:0.84958
# [192]	train-auc:0.94812	valid-auc:0.84945
# [193]	train-auc:0.94845	valid-auc:0.84940
# [194]	train-auc:0.94878	valid-auc:0.84940
# [195]	train-auc:0.94908	valid-auc:0.84937
# [196]	train-auc:0.94937	valid-auc:0.84936
# [197]	train-auc:0.94969	valid-auc:0.84937
# [198]	train-auc:0.94994	valid-auc:0.84937
# [199]	train-auc:0.95011	valid-auc:0.84934
# [200]	train-auc:0.95038	valid-auc:0.84957
# [201]	train-auc:0.95072	valid-auc:0.84949
# [202]	train-auc:0.95110	valid-auc:0.84945
# [203]	train-auc:0.95142	valid-auc:0.84944
# [204]	train-auc:0.95153	valid-auc:0.84952
# [205]	train-auc:0.95182	valid-auc:0.84953
# [206]	train-auc:0.95218	valid-auc:0.84962
# [207]	train-auc:0.95246	valid-auc:0.84968
# [208]	train-auc:0.95281	valid-auc:0.84967
# [209]	train-auc:0.95323	valid-auc:0.84962
# Stopping. Best iteration:
# [189]	train-auc:0.94710	valid-auc:0.84969
#
# fit severe_toxic
# [0]	train-auc:0.85766	valid-auc:0.83768
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.89979	valid-auc:0.88532
# [2]	train-auc:0.91025	valid-auc:0.89689
# [3]	train-auc:0.91253	valid-auc:0.89875
# [4]	train-auc:0.91798	valid-auc:0.90366
# [5]	train-auc:0.92372	valid-auc:0.90312
# [6]	train-auc:0.92883	valid-auc:0.90048
# [7]	train-auc:0.92954	valid-auc:0.90126
# [8]	train-auc:0.93034	valid-auc:0.90140
# [9]	train-auc:0.93464	valid-auc:0.90455
# [10]	train-auc:0.93776	valid-auc:0.90777
# [11]	train-auc:0.94019	valid-auc:0.91065
# [12]	train-auc:0.94110	valid-auc:0.91031
# [13]	train-auc:0.94169	valid-auc:0.91096
# [14]	train-auc:0.94420	valid-auc:0.91273
# [15]	train-auc:0.94454	valid-auc:0.91312
# [16]	train-auc:0.94729	valid-auc:0.91488
# [17]	train-auc:0.95153	valid-auc:0.91801
# [18]	train-auc:0.95266	valid-auc:0.91847
# [19]	train-auc:0.95378	valid-auc:0.91838
# [20]	train-auc:0.95441	valid-auc:0.91854
# [21]	train-auc:0.95710	valid-auc:0.91911
# [22]	train-auc:0.95894	valid-auc:0.92038
# [23]	train-auc:0.96002	valid-auc:0.92141
# [24]	train-auc:0.96120	valid-auc:0.92146
# [25]	train-auc:0.96134	valid-auc:0.92109
# [26]	train-auc:0.96200	valid-auc:0.92034
# [27]	train-auc:0.96315	valid-auc:0.92021
# [28]	train-auc:0.96337	valid-auc:0.92001
# [29]	train-auc:0.96473	valid-auc:0.92087
# [30]	train-auc:0.96611	valid-auc:0.92010
# [31]	train-auc:0.96741	valid-auc:0.92074
# [32]	train-auc:0.96800	valid-auc:0.92119
# [33]	train-auc:0.96875	valid-auc:0.92148
# [34]	train-auc:0.96920	valid-auc:0.92217
# [35]	train-auc:0.96987	valid-auc:0.92448
# [36]	train-auc:0.97098	valid-auc:0.92453
# [37]	train-auc:0.97262	valid-auc:0.92593
# [38]	train-auc:0.97343	valid-auc:0.92555
# [39]	train-auc:0.97416	valid-auc:0.92640
# [40]	train-auc:0.97453	valid-auc:0.92519
# [41]	train-auc:0.97517	valid-auc:0.92600
# [42]	train-auc:0.97570	valid-auc:0.92896
# [43]	train-auc:0.97664	valid-auc:0.93051
# [44]	train-auc:0.97712	valid-auc:0.93185
# [45]	train-auc:0.97799	valid-auc:0.93201
# [46]	train-auc:0.97859	valid-auc:0.93206
# [47]	train-auc:0.97909	valid-auc:0.93240
# [48]	train-auc:0.98031	valid-auc:0.93260
# [49]	train-auc:0.98128	valid-auc:0.93297
# [50]	train-auc:0.98272	valid-auc:0.93275
# [51]	train-auc:0.98294	valid-auc:0.93264
# [52]	train-auc:0.98332	valid-auc:0.93303
# [53]	train-auc:0.98400	valid-auc:0.93285
# [54]	train-auc:0.98519	valid-auc:0.93483
# [55]	train-auc:0.98547	valid-auc:0.93483
# [56]	train-auc:0.98601	valid-auc:0.93511
# [57]	train-auc:0.98655	valid-auc:0.93519
# [58]	train-auc:0.98690	valid-auc:0.93458
# [59]	train-auc:0.98726	valid-auc:0.93495
# [60]	train-auc:0.98747	valid-auc:0.93424
# [61]	train-auc:0.98802	valid-auc:0.93473
# [62]	train-auc:0.98837	valid-auc:0.93463
# [63]	train-auc:0.98886	valid-auc:0.93432
# [64]	train-auc:0.98925	valid-auc:0.93453
# [65]	train-auc:0.98954	valid-auc:0.93475
# [66]	train-auc:0.98995	valid-auc:0.93473
# [67]	train-auc:0.99013	valid-auc:0.93466
# [68]	train-auc:0.99062	valid-auc:0.93565
# [69]	train-auc:0.99093	valid-auc:0.93584
# [70]	train-auc:0.99134	valid-auc:0.93623
# [71]	train-auc:0.99162	valid-auc:0.93655
# [72]	train-auc:0.99188	valid-auc:0.93692
# [73]	train-auc:0.99216	valid-auc:0.93695
# [74]	train-auc:0.99229	valid-auc:0.93665
# [75]	train-auc:0.99247	valid-auc:0.93576
# [76]	train-auc:0.99268	valid-auc:0.93655
# [77]	train-auc:0.99295	valid-auc:0.93661
# [78]	train-auc:0.99313	valid-auc:0.93706
# [79]	train-auc:0.99326	valid-auc:0.93727
# [80]	train-auc:0.99343	valid-auc:0.93734
# [81]	train-auc:0.99365	valid-auc:0.93708
# [82]	train-auc:0.99378	valid-auc:0.93699
# [83]	train-auc:0.99394	valid-auc:0.93686
# [84]	train-auc:0.99412	valid-auc:0.93707
# [85]	train-auc:0.99428	valid-auc:0.93696
# [86]	train-auc:0.99437	valid-auc:0.93655
# [87]	train-auc:0.99441	valid-auc:0.93638
# [88]	train-auc:0.99457	valid-auc:0.93621
# [89]	train-auc:0.99467	valid-auc:0.93623
# [90]	train-auc:0.99481	valid-auc:0.93637
# [91]	train-auc:0.99518	valid-auc:0.93623
# [92]	train-auc:0.99531	valid-auc:0.93621
# [93]	train-auc:0.99544	valid-auc:0.93594
# [94]	train-auc:0.99558	valid-auc:0.93596
# [95]	train-auc:0.99577	valid-auc:0.93534
# [96]	train-auc:0.99580	valid-auc:0.93558
# [97]	train-auc:0.99596	valid-auc:0.93550
# [98]	train-auc:0.99608	valid-auc:0.93580
# [99]	train-auc:0.99616	valid-auc:0.93553
# [100]	train-auc:0.99631	valid-auc:0.93598
# Stopping. Best iteration:
# [80]	train-auc:0.99343	valid-auc:0.93734
#
# fit obscene
# [0]	train-auc:0.81029	valid-auc:0.80763
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.83375	valid-auc:0.82373
# [2]	train-auc:0.83976	valid-auc:0.82783
# [3]	train-auc:0.84672	valid-auc:0.83432
# [4]	train-auc:0.85025	valid-auc:0.83616
# [5]	train-auc:0.85346	valid-auc:0.83940
# [6]	train-auc:0.85564	valid-auc:0.84183
# [7]	train-auc:0.85731	valid-auc:0.84494
# [8]	train-auc:0.85859	valid-auc:0.84520
# [9]	train-auc:0.86037	valid-auc:0.84560
# [10]	train-auc:0.86087	valid-auc:0.84563
# [11]	train-auc:0.86417	valid-auc:0.84665
# [12]	train-auc:0.86586	valid-auc:0.84792
# [13]	train-auc:0.86771	valid-auc:0.84932
# [14]	train-auc:0.86811	valid-auc:0.84895
# [15]	train-auc:0.86915	valid-auc:0.84978
# [16]	train-auc:0.87137	valid-auc:0.85075
# [17]	train-auc:0.87278	valid-auc:0.85169
# [18]	train-auc:0.87486	valid-auc:0.85232
# [19]	train-auc:0.87648	valid-auc:0.85316
# [20]	train-auc:0.87766	valid-auc:0.85421
# [21]	train-auc:0.87905	valid-auc:0.85541
# [22]	train-auc:0.88089	valid-auc:0.85698
# [23]	train-auc:0.88234	valid-auc:0.85795
# [24]	train-auc:0.88385	valid-auc:0.85870
# [25]	train-auc:0.88520	valid-auc:0.85959
# [26]	train-auc:0.88630	valid-auc:0.85967
# [27]	train-auc:0.88787	valid-auc:0.86122
# [28]	train-auc:0.88872	valid-auc:0.86187
# [29]	train-auc:0.88994	valid-auc:0.86262
# [30]	train-auc:0.89120	valid-auc:0.86296
# [31]	train-auc:0.89222	valid-auc:0.86364
# [32]	train-auc:0.89388	valid-auc:0.86418
# [33]	train-auc:0.89514	valid-auc:0.86458
# [34]	train-auc:0.89623	valid-auc:0.86462
# [35]	train-auc:0.89782	valid-auc:0.86527
# [36]	train-auc:0.89906	valid-auc:0.86632
# [37]	train-auc:0.90033	valid-auc:0.86704
# [38]	train-auc:0.90154	valid-auc:0.86789
# [39]	train-auc:0.90286	valid-auc:0.86876
# [40]	train-auc:0.90434	valid-auc:0.86908
# [41]	train-auc:0.90539	valid-auc:0.86941
# [42]	train-auc:0.90703	valid-auc:0.86986
# [43]	train-auc:0.90822	valid-auc:0.87092
# [44]	train-auc:0.90969	valid-auc:0.87138
# [45]	train-auc:0.91073	valid-auc:0.87181
# [46]	train-auc:0.91164	valid-auc:0.87234
# [47]	train-auc:0.91288	valid-auc:0.87294
# [48]	train-auc:0.91385	valid-auc:0.87348
# [49]	train-auc:0.91476	valid-auc:0.87391
# [50]	train-auc:0.91592	valid-auc:0.87409
# [51]	train-auc:0.91686	valid-auc:0.87439
# [52]	train-auc:0.91767	valid-auc:0.87446
# [53]	train-auc:0.91864	valid-auc:0.87485
# [54]	train-auc:0.91987	valid-auc:0.87513
# [55]	train-auc:0.92080	valid-auc:0.87541
# [56]	train-auc:0.92188	valid-auc:0.87555
# [57]	train-auc:0.92299	valid-auc:0.87574
# [58]	train-auc:0.92359	valid-auc:0.87605
# [59]	train-auc:0.92444	valid-auc:0.87626
# [60]	train-auc:0.92523	valid-auc:0.87656
# [61]	train-auc:0.92607	valid-auc:0.87694
# [62]	train-auc:0.92717	valid-auc:0.87743
# [63]	train-auc:0.92780	valid-auc:0.87767
# [64]	train-auc:0.92854	valid-auc:0.87811
# [65]	train-auc:0.92929	valid-auc:0.87811
# [66]	train-auc:0.93000	valid-auc:0.87843
# [67]	train-auc:0.93092	valid-auc:0.87837
# [68]	train-auc:0.93149	valid-auc:0.87836
# [69]	train-auc:0.93208	valid-auc:0.87876
# [70]	train-auc:0.93261	valid-auc:0.87909
# [71]	train-auc:0.93321	valid-auc:0.87938
# [72]	train-auc:0.93447	valid-auc:0.88011
# [73]	train-auc:0.93511	valid-auc:0.88040
# [74]	train-auc:0.93593	valid-auc:0.88046
# [75]	train-auc:0.93690	valid-auc:0.88091
# [76]	train-auc:0.93778	valid-auc:0.88087
# [77]	train-auc:0.93826	valid-auc:0.88090
# [78]	train-auc:0.93899	valid-auc:0.88093
# [79]	train-auc:0.93970	valid-auc:0.88098
# [80]	train-auc:0.94049	valid-auc:0.88102
# [81]	train-auc:0.94107	valid-auc:0.88123
# [82]	train-auc:0.94171	valid-auc:0.88147
# [83]	train-auc:0.94210	valid-auc:0.88144
# [84]	train-auc:0.94245	valid-auc:0.88132
# [85]	train-auc:0.94290	valid-auc:0.88159
# [86]	train-auc:0.94342	valid-auc:0.88208
# [87]	train-auc:0.94392	valid-auc:0.88250
# [88]	train-auc:0.94443	valid-auc:0.88259
# [89]	train-auc:0.94494	valid-auc:0.88303
# [90]	train-auc:0.94540	valid-auc:0.88296
# [91]	train-auc:0.94577	valid-auc:0.88276
# [92]	train-auc:0.94638	valid-auc:0.88279
# [93]	train-auc:0.94673	valid-auc:0.88284
# [94]	train-auc:0.94701	valid-auc:0.88292
# [95]	train-auc:0.94753	valid-auc:0.88315
# [96]	train-auc:0.94795	valid-auc:0.88336
# [97]	train-auc:0.94848	valid-auc:0.88334
# [98]	train-auc:0.94899	valid-auc:0.88337
# [99]	train-auc:0.94927	valid-auc:0.88313
# [100]	train-auc:0.94944	valid-auc:0.88311
# [101]	train-auc:0.94990	valid-auc:0.88327
# [102]	train-auc:0.95017	valid-auc:0.88341
# [103]	train-auc:0.95082	valid-auc:0.88355
# [104]	train-auc:0.95134	valid-auc:0.88375
# [105]	train-auc:0.95182	valid-auc:0.88397
# [106]	train-auc:0.95247	valid-auc:0.88418
# [107]	train-auc:0.95310	valid-auc:0.88423
# [108]	train-auc:0.95349	valid-auc:0.88440
# [109]	train-auc:0.95410	valid-auc:0.88450
# [110]	train-auc:0.95462	valid-auc:0.88472
# [111]	train-auc:0.95503	valid-auc:0.88458
# [112]	train-auc:0.95528	valid-auc:0.88457
# [113]	train-auc:0.95584	valid-auc:0.88467
# [114]	train-auc:0.95624	valid-auc:0.88499
# [115]	train-auc:0.95676	valid-auc:0.88484
# [116]	train-auc:0.95736	valid-auc:0.88492
# [117]	train-auc:0.95784	valid-auc:0.88502
# [118]	train-auc:0.95811	valid-auc:0.88497
# [119]	train-auc:0.95839	valid-auc:0.88484
# [120]	train-auc:0.95856	valid-auc:0.88489
# [121]	train-auc:0.95876	valid-auc:0.88480
# [122]	train-auc:0.95928	valid-auc:0.88489
# [123]	train-auc:0.95985	valid-auc:0.88517
# [124]	train-auc:0.96018	valid-auc:0.88524
# [125]	train-auc:0.96046	valid-auc:0.88519
# [126]	train-auc:0.96095	valid-auc:0.88523
# [127]	train-auc:0.96151	valid-auc:0.88521
# [128]	train-auc:0.96189	valid-auc:0.88529
# [129]	train-auc:0.96235	valid-auc:0.88553
# [130]	train-auc:0.96271	valid-auc:0.88544
# [131]	train-auc:0.96303	valid-auc:0.88557
# [132]	train-auc:0.96320	valid-auc:0.88561
# [133]	train-auc:0.96350	valid-auc:0.88573
# [134]	train-auc:0.96384	valid-auc:0.88572
# [135]	train-auc:0.96406	valid-auc:0.88560
# [136]	train-auc:0.96445	valid-auc:0.88551
# [137]	train-auc:0.96485	valid-auc:0.88590
# [138]	train-auc:0.96521	valid-auc:0.88593
# [139]	train-auc:0.96562	valid-auc:0.88602
# [140]	train-auc:0.96588	valid-auc:0.88605
# [141]	train-auc:0.96617	valid-auc:0.88611
# [142]	train-auc:0.96644	valid-auc:0.88604
# [143]	train-auc:0.96689	valid-auc:0.88616
# [144]	train-auc:0.96742	valid-auc:0.88596
# [145]	train-auc:0.96785	valid-auc:0.88602
# [146]	train-auc:0.96802	valid-auc:0.88601
# [147]	train-auc:0.96834	valid-auc:0.88626
# [148]	train-auc:0.96866	valid-auc:0.88613
# [149]	train-auc:0.96894	valid-auc:0.88609
# [150]	train-auc:0.96938	valid-auc:0.88605
# [151]	train-auc:0.96968	valid-auc:0.88620
# [152]	train-auc:0.96984	valid-auc:0.88620
# [153]	train-auc:0.97017	valid-auc:0.88606
# [154]	train-auc:0.97036	valid-auc:0.88602
# [155]	train-auc:0.97056	valid-auc:0.88588
# [156]	train-auc:0.97106	valid-auc:0.88575
# [157]	train-auc:0.97156	valid-auc:0.88552
# [158]	train-auc:0.97185	valid-auc:0.88548
# [159]	train-auc:0.97216	valid-auc:0.88562
# [160]	train-auc:0.97235	valid-auc:0.88576
# [161]	train-auc:0.97244	valid-auc:0.88573
# [162]	train-auc:0.97266	valid-auc:0.88571
# [163]	train-auc:0.97299	valid-auc:0.88559
# [164]	train-auc:0.97332	valid-auc:0.88536
# [165]	train-auc:0.97354	valid-auc:0.88528
# [166]	train-auc:0.97381	valid-auc:0.88531
# [167]	train-auc:0.97396	valid-auc:0.88538
# Stopping. Best iteration:
# [147]	train-auc:0.96834	valid-auc:0.88626
#
# fit threat
# [0]	train-auc:0.71563	valid-auc:0.71289
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79396	valid-auc:0.78768
# [2]	train-auc:0.79622	valid-auc:0.78852
# [3]	train-auc:0.81663	valid-auc:0.80806
# [4]	train-auc:0.84568	valid-auc:0.83985
# [5]	train-auc:0.87035	valid-auc:0.83337
# [6]	train-auc:0.87202	valid-auc:0.83637
# [7]	train-auc:0.87328	valid-auc:0.83409
# [8]	train-auc:0.87294	valid-auc:0.83574
# [9]	train-auc:0.87925	valid-auc:0.85222
# [10]	train-auc:0.88277	valid-auc:0.84939
# [11]	train-auc:0.89293	valid-auc:0.86586
# [12]	train-auc:0.89329	valid-auc:0.86455
# [13]	train-auc:0.89574	valid-auc:0.86699
# [14]	train-auc:0.89575	valid-auc:0.86760
# [15]	train-auc:0.89720	valid-auc:0.86970
# [16]	train-auc:0.90467	valid-auc:0.86838
# [17]	train-auc:0.90836	valid-auc:0.88059
# [18]	train-auc:0.91022	valid-auc:0.88064
# [19]	train-auc:0.91174	valid-auc:0.87920
# [20]	train-auc:0.91318	valid-auc:0.88001
# [21]	train-auc:0.91451	valid-auc:0.88210
# [22]	train-auc:0.91787	valid-auc:0.88518
# [23]	train-auc:0.92146	valid-auc:0.90303
# [24]	train-auc:0.92426	valid-auc:0.90415
# [25]	train-auc:0.93283	valid-auc:0.91626
# [26]	train-auc:0.93287	valid-auc:0.91477
# [27]	train-auc:0.93838	valid-auc:0.91437
# [28]	train-auc:0.93897	valid-auc:0.91531
# [29]	train-auc:0.94157	valid-auc:0.91288
# [30]	train-auc:0.94383	valid-auc:0.91267
# [31]	train-auc:0.94599	valid-auc:0.91195
# [32]	train-auc:0.94863	valid-auc:0.91021
# [33]	train-auc:0.94963	valid-auc:0.91077
# [34]	train-auc:0.95076	valid-auc:0.90907
# [35]	train-auc:0.95140	valid-auc:0.90826
# [36]	train-auc:0.95272	valid-auc:0.90943
# [37]	train-auc:0.95620	valid-auc:0.91514
# [38]	train-auc:0.95647	valid-auc:0.91344
# [39]	train-auc:0.95781	valid-auc:0.91404
# [40]	train-auc:0.95863	valid-auc:0.91504
# [41]	train-auc:0.96063	valid-auc:0.91348
# [42]	train-auc:0.96384	valid-auc:0.91258
# [43]	train-auc:0.96429	valid-auc:0.91414
# [44]	train-auc:0.96439	valid-auc:0.91322
# [45]	train-auc:0.96610	valid-auc:0.91667
# [46]	train-auc:0.96757	valid-auc:0.91711
# [47]	train-auc:0.97047	valid-auc:0.92103
# [48]	train-auc:0.97234	valid-auc:0.91998
# [49]	train-auc:0.97324	valid-auc:0.92165
# [50]	train-auc:0.97355	valid-auc:0.92123
# [51]	train-auc:0.97550	valid-auc:0.92025
# [52]	train-auc:0.97632	valid-auc:0.91828
# [53]	train-auc:0.97711	valid-auc:0.91843
# [54]	train-auc:0.97916	valid-auc:0.91731
# [55]	train-auc:0.98031	valid-auc:0.91920
# [56]	train-auc:0.98133	valid-auc:0.92033
# [57]	train-auc:0.98328	valid-auc:0.92149
# [58]	train-auc:0.98450	valid-auc:0.92270
# [59]	train-auc:0.98492	valid-auc:0.92261
# [60]	train-auc:0.98531	valid-auc:0.92171
# [61]	train-auc:0.98742	valid-auc:0.92190
# [62]	train-auc:0.98775	valid-auc:0.92428
# [63]	train-auc:0.98807	valid-auc:0.92432
# [64]	train-auc:0.98887	valid-auc:0.92367
# [65]	train-auc:0.98967	valid-auc:0.92245
# [66]	train-auc:0.99049	valid-auc:0.92161
# [67]	train-auc:0.99173	valid-auc:0.92043
# [68]	train-auc:0.99272	valid-auc:0.91963
# [69]	train-auc:0.99328	valid-auc:0.92008
# [70]	train-auc:0.99355	valid-auc:0.92058
# [71]	train-auc:0.99394	valid-auc:0.92088
# [72]	train-auc:0.99416	valid-auc:0.92076
# [73]	train-auc:0.99464	valid-auc:0.92218
# [74]	train-auc:0.99478	valid-auc:0.92048
# [75]	train-auc:0.99494	valid-auc:0.91997
# [76]	train-auc:0.99509	valid-auc:0.92001
# [77]	train-auc:0.99536	valid-auc:0.91929
# [78]	train-auc:0.99597	valid-auc:0.91828
# [79]	train-auc:0.99621	valid-auc:0.91949
# [80]	train-auc:0.99689	valid-auc:0.91728
# [81]	train-auc:0.99713	valid-auc:0.91607
# [82]	train-auc:0.99721	valid-auc:0.91565
# [83]	train-auc:0.99743	valid-auc:0.91339
# Stopping. Best iteration:
# [63]	train-auc:0.98807	valid-auc:0.92432
#
# fit insult
# [0]	train-auc:0.80918	valid-auc:0.78961
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.83503	valid-auc:0.81051
# [2]	train-auc:0.84569	valid-auc:0.82178
# [3]	train-auc:0.85203	valid-auc:0.82632
# [4]	train-auc:0.85665	valid-auc:0.83310
# [5]	train-auc:0.85914	valid-auc:0.83474
# [6]	train-auc:0.86137	valid-auc:0.83581
# [7]	train-auc:0.86326	valid-auc:0.83752
# [8]	train-auc:0.86410	valid-auc:0.83787
# [9]	train-auc:0.86525	valid-auc:0.83874
# [10]	train-auc:0.86661	valid-auc:0.84013
# [11]	train-auc:0.86838	valid-auc:0.84093
# [12]	train-auc:0.86969	valid-auc:0.84281
# [13]	train-auc:0.87121	valid-auc:0.84389
# [14]	train-auc:0.87209	valid-auc:0.84345
# [15]	train-auc:0.87354	valid-auc:0.84408
# [16]	train-auc:0.87505	valid-auc:0.84507
# [17]	train-auc:0.87692	valid-auc:0.84600
# [18]	train-auc:0.87932	valid-auc:0.84746
# [19]	train-auc:0.88145	valid-auc:0.84911
# [20]	train-auc:0.88242	valid-auc:0.85005
# [21]	train-auc:0.88385	valid-auc:0.85054
# [22]	train-auc:0.88520	valid-auc:0.85092
# [23]	train-auc:0.88665	valid-auc:0.85225
# [24]	train-auc:0.88758	valid-auc:0.85298
# [25]	train-auc:0.88888	valid-auc:0.85402
# [26]	train-auc:0.89007	valid-auc:0.85414
# [27]	train-auc:0.89166	valid-auc:0.85448
# [28]	train-auc:0.89286	valid-auc:0.85468
# [29]	train-auc:0.89431	valid-auc:0.85542
# [30]	train-auc:0.89568	valid-auc:0.85607
# [31]	train-auc:0.89652	valid-auc:0.85703
# [32]	train-auc:0.89756	valid-auc:0.85739
# [33]	train-auc:0.89889	valid-auc:0.85822
# [34]	train-auc:0.90023	valid-auc:0.85921
# [35]	train-auc:0.90159	valid-auc:0.85957
# [36]	train-auc:0.90288	valid-auc:0.86000
# [37]	train-auc:0.90407	valid-auc:0.86038
# [38]	train-auc:0.90558	valid-auc:0.86072
# [39]	train-auc:0.90682	valid-auc:0.86133
# [40]	train-auc:0.90814	valid-auc:0.86191
# [41]	train-auc:0.90913	valid-auc:0.86225
# [42]	train-auc:0.91037	valid-auc:0.86295
# [43]	train-auc:0.91146	valid-auc:0.86348
# [44]	train-auc:0.91251	valid-auc:0.86396
# [45]	train-auc:0.91380	valid-auc:0.86409
# [46]	train-auc:0.91478	valid-auc:0.86493
# [47]	train-auc:0.91613	valid-auc:0.86548
# [48]	train-auc:0.91725	valid-auc:0.86549
# [49]	train-auc:0.91826	valid-auc:0.86547
# [50]	train-auc:0.91912	valid-auc:0.86614
# [51]	train-auc:0.92009	valid-auc:0.86651
# [52]	train-auc:0.92092	valid-auc:0.86693
# [53]	train-auc:0.92176	valid-auc:0.86714
# [54]	train-auc:0.92258	valid-auc:0.86767
# [55]	train-auc:0.92349	valid-auc:0.86798
# [56]	train-auc:0.92431	valid-auc:0.86838
# [57]	train-auc:0.92530	valid-auc:0.86865
# [58]	train-auc:0.92618	valid-auc:0.86883
# [59]	train-auc:0.92709	valid-auc:0.86938
# [60]	train-auc:0.92783	valid-auc:0.87003
# [61]	train-auc:0.92860	valid-auc:0.87021
# [62]	train-auc:0.92927	valid-auc:0.87039
# [63]	train-auc:0.92991	valid-auc:0.87061
# [64]	train-auc:0.93043	valid-auc:0.87048
# [65]	train-auc:0.93111	valid-auc:0.87028
# [66]	train-auc:0.93165	valid-auc:0.87047
# [67]	train-auc:0.93228	valid-auc:0.87066
# [68]	train-auc:0.93296	valid-auc:0.87072
# [69]	train-auc:0.93352	valid-auc:0.87086
# [70]	train-auc:0.93394	valid-auc:0.87128
# [71]	train-auc:0.93468	valid-auc:0.87134
# [72]	train-auc:0.93512	valid-auc:0.87153
# [73]	train-auc:0.93572	valid-auc:0.87181
# [74]	train-auc:0.93648	valid-auc:0.87205
# [75]	train-auc:0.93729	valid-auc:0.87266
# [76]	train-auc:0.93771	valid-auc:0.87306
# [77]	train-auc:0.93885	valid-auc:0.87333
# [78]	train-auc:0.93944	valid-auc:0.87339
# [79]	train-auc:0.93978	valid-auc:0.87351
# [80]	train-auc:0.94039	valid-auc:0.87387
# [81]	train-auc:0.94067	valid-auc:0.87384
# [82]	train-auc:0.94114	valid-auc:0.87406
# [83]	train-auc:0.94169	valid-auc:0.87413
# [84]	train-auc:0.94191	valid-auc:0.87421
# [85]	train-auc:0.94227	valid-auc:0.87450
# [86]	train-auc:0.94273	valid-auc:0.87474
# [87]	train-auc:0.94338	valid-auc:0.87481
# [88]	train-auc:0.94378	valid-auc:0.87485
# [89]	train-auc:0.94448	valid-auc:0.87489
# [90]	train-auc:0.94502	valid-auc:0.87511
# [91]	train-auc:0.94569	valid-auc:0.87547
# [92]	train-auc:0.94589	valid-auc:0.87574
# [93]	train-auc:0.94627	valid-auc:0.87580
# [94]	train-auc:0.94697	valid-auc:0.87610
# [95]	train-auc:0.94764	valid-auc:0.87639
# [96]	train-auc:0.94816	valid-auc:0.87652
# [97]	train-auc:0.94870	valid-auc:0.87671
# [98]	train-auc:0.94903	valid-auc:0.87689
# [99]	train-auc:0.94982	valid-auc:0.87720
# [100]	train-auc:0.95048	valid-auc:0.87727
# [101]	train-auc:0.95089	valid-auc:0.87726
# [102]	train-auc:0.95117	valid-auc:0.87723
# [103]	train-auc:0.95187	valid-auc:0.87740
# [104]	train-auc:0.95227	valid-auc:0.87738
# [105]	train-auc:0.95250	valid-auc:0.87738
# [106]	train-auc:0.95290	valid-auc:0.87757
# [107]	train-auc:0.95320	valid-auc:0.87774
# [108]	train-auc:0.95373	valid-auc:0.87760
# [109]	train-auc:0.95405	valid-auc:0.87762
# [110]	train-auc:0.95462	valid-auc:0.87753
# [111]	train-auc:0.95484	valid-auc:0.87750
# [112]	train-auc:0.95501	valid-auc:0.87746
# [113]	train-auc:0.95528	valid-auc:0.87758
# [114]	train-auc:0.95564	valid-auc:0.87775
# [115]	train-auc:0.95606	valid-auc:0.87775
# [116]	train-auc:0.95639	valid-auc:0.87799
# [117]	train-auc:0.95675	valid-auc:0.87811
# [118]	train-auc:0.95724	valid-auc:0.87832
# [119]	train-auc:0.95759	valid-auc:0.87834
# [120]	train-auc:0.95784	valid-auc:0.87842
# [121]	train-auc:0.95817	valid-auc:0.87828
# [122]	train-auc:0.95879	valid-auc:0.87844
# [123]	train-auc:0.95927	valid-auc:0.87864
# [124]	train-auc:0.95943	valid-auc:0.87867
# [125]	train-auc:0.95974	valid-auc:0.87878
# [126]	train-auc:0.96023	valid-auc:0.87886
# [127]	train-auc:0.96053	valid-auc:0.87869
# [128]	train-auc:0.96096	valid-auc:0.87875
# [129]	train-auc:0.96131	valid-auc:0.87885
# [130]	train-auc:0.96162	valid-auc:0.87882
# [131]	train-auc:0.96203	valid-auc:0.87901
# [132]	train-auc:0.96252	valid-auc:0.87917
# [133]	train-auc:0.96267	valid-auc:0.87915
# [134]	train-auc:0.96282	valid-auc:0.87937
# [135]	train-auc:0.96305	valid-auc:0.87940
# [136]	train-auc:0.96335	valid-auc:0.87916
# [137]	train-auc:0.96378	valid-auc:0.87925
# [138]	train-auc:0.96431	valid-auc:0.87928
# [139]	train-auc:0.96472	valid-auc:0.87913
# [140]	train-auc:0.96507	valid-auc:0.87914
# [141]	train-auc:0.96515	valid-auc:0.87904
# [142]	train-auc:0.96562	valid-auc:0.87927
# [143]	train-auc:0.96598	valid-auc:0.87943
# [144]	train-auc:0.96630	valid-auc:0.87964
# [145]	train-auc:0.96676	valid-auc:0.88005
# [146]	train-auc:0.96715	valid-auc:0.88026
# [147]	train-auc:0.96737	valid-auc:0.88032
# [148]	train-auc:0.96775	valid-auc:0.88046
# [149]	train-auc:0.96812	valid-auc:0.88063
# [150]	train-auc:0.96849	valid-auc:0.88072
# [151]	train-auc:0.96863	valid-auc:0.88077
# [152]	train-auc:0.96877	valid-auc:0.88091
# [153]	train-auc:0.96894	valid-auc:0.88083
# [154]	train-auc:0.96910	valid-auc:0.88086
# [155]	train-auc:0.96939	valid-auc:0.88070
# [156]	train-auc:0.96950	valid-auc:0.88091
# [157]	train-auc:0.96986	valid-auc:0.88092
# [158]	train-auc:0.97014	valid-auc:0.88096
# [159]	train-auc:0.97060	valid-auc:0.88081
# [160]	train-auc:0.97086	valid-auc:0.88075
# [161]	train-auc:0.97106	valid-auc:0.88091
# [162]	train-auc:0.97137	valid-auc:0.88106
# [163]	train-auc:0.97196	valid-auc:0.88147
# [164]	train-auc:0.97232	valid-auc:0.88135
# [165]	train-auc:0.97258	valid-auc:0.88157
# [166]	train-auc:0.97279	valid-auc:0.88172
# [167]	train-auc:0.97304	valid-auc:0.88174
# [168]	train-auc:0.97335	valid-auc:0.88185
# [169]	train-auc:0.97355	valid-auc:0.88182
# [170]	train-auc:0.97371	valid-auc:0.88199
# [171]	train-auc:0.97387	valid-auc:0.88201
# [172]	train-auc:0.97428	valid-auc:0.88207
# [173]	train-auc:0.97459	valid-auc:0.88213
# [174]	train-auc:0.97477	valid-auc:0.88200
# [175]	train-auc:0.97482	valid-auc:0.88192
# [176]	train-auc:0.97492	valid-auc:0.88199
# [177]	train-auc:0.97508	valid-auc:0.88196
# [178]	train-auc:0.97545	valid-auc:0.88191
# [179]	train-auc:0.97573	valid-auc:0.88172
# [180]	train-auc:0.97608	valid-auc:0.88176
# [181]	train-auc:0.97630	valid-auc:0.88162
# [182]	train-auc:0.97651	valid-auc:0.88168
# [183]	train-auc:0.97696	valid-auc:0.88165
# [184]	train-auc:0.97709	valid-auc:0.88169
# [185]	train-auc:0.97721	valid-auc:0.88158
# [186]	train-auc:0.97746	valid-auc:0.88151
# [187]	train-auc:0.97750	valid-auc:0.88155
# [188]	train-auc:0.97768	valid-auc:0.88146
# [189]	train-auc:0.97795	valid-auc:0.88180
# [190]	train-auc:0.97818	valid-auc:0.88193
# [191]	train-auc:0.97840	valid-auc:0.88193
# [192]	train-auc:0.97865	valid-auc:0.88178
# [193]	train-auc:0.97883	valid-auc:0.88188
# Stopping. Best iteration:
# [173]	train-auc:0.97459	valid-auc:0.88213
#
# fit identity_hate
# [0]	train-auc:0.75846	valid-auc:0.72976
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79417	valid-auc:0.75317
# [2]	train-auc:0.83090	valid-auc:0.77848
# [3]	train-auc:0.84142	valid-auc:0.78355
# [4]	train-auc:0.84452	valid-auc:0.78238
# [5]	train-auc:0.85071	valid-auc:0.79505
# [6]	train-auc:0.85183	valid-auc:0.79550
# [7]	train-auc:0.85674	valid-auc:0.79905
# [8]	train-auc:0.86070	valid-auc:0.79721
# [9]	train-auc:0.86059	valid-auc:0.79745
# [10]	train-auc:0.86176	valid-auc:0.79769
# [11]	train-auc:0.86817	valid-auc:0.79932
# [12]	train-auc:0.86894	valid-auc:0.79829
# [13]	train-auc:0.87374	valid-auc:0.80427
# [14]	train-auc:0.87626	valid-auc:0.80722
# [15]	train-auc:0.87652	valid-auc:0.80829
# [16]	train-auc:0.88046	valid-auc:0.81161
# [17]	train-auc:0.88180	valid-auc:0.81309
# [18]	train-auc:0.88419	valid-auc:0.81728
# [19]	train-auc:0.88458	valid-auc:0.81865
# [20]	train-auc:0.88523	valid-auc:0.82039
# [21]	train-auc:0.89000	valid-auc:0.82568
# [22]	train-auc:0.89182	valid-auc:0.82853
# [23]	train-auc:0.89565	valid-auc:0.82918
# [24]	train-auc:0.89905	valid-auc:0.83205
# [25]	train-auc:0.89995	valid-auc:0.83546
# [26]	train-auc:0.90253	valid-auc:0.83430
# [27]	train-auc:0.90592	valid-auc:0.83389
# [28]	train-auc:0.90788	valid-auc:0.83542
# [29]	train-auc:0.91049	valid-auc:0.83652
# [30]	train-auc:0.91192	valid-auc:0.83557
# [31]	train-auc:0.91454	valid-auc:0.83557
# [32]	train-auc:0.91540	valid-auc:0.83579
# [33]	train-auc:0.91874	valid-auc:0.83491
# [34]	train-auc:0.92003	valid-auc:0.83345
# [35]	train-auc:0.92365	valid-auc:0.83654
# [36]	train-auc:0.92626	valid-auc:0.83737
# [37]	train-auc:0.92829	valid-auc:0.83659
# [38]	train-auc:0.92878	valid-auc:0.83788
# [39]	train-auc:0.93043	valid-auc:0.84028
# [40]	train-auc:0.93329	valid-auc:0.84049
# [41]	train-auc:0.93482	valid-auc:0.83957
# [42]	train-auc:0.93653	valid-auc:0.84003
# [43]	train-auc:0.93901	valid-auc:0.84426
# [44]	train-auc:0.94160	valid-auc:0.84574
# [45]	train-auc:0.94303	valid-auc:0.84511
# [46]	train-auc:0.94559	valid-auc:0.84330
# [47]	train-auc:0.94813	valid-auc:0.84480
# [48]	train-auc:0.94975	valid-auc:0.84720
# [49]	train-auc:0.95187	valid-auc:0.84751
# [50]	train-auc:0.95385	valid-auc:0.84832
# [51]	train-auc:0.95489	valid-auc:0.84895
# [52]	train-auc:0.95578	valid-auc:0.84928
# [53]	train-auc:0.95750	valid-auc:0.84914
# [54]	train-auc:0.96015	valid-auc:0.85105
# [55]	train-auc:0.96193	valid-auc:0.85161
# [56]	train-auc:0.96288	valid-auc:0.85086
# [57]	train-auc:0.96459	valid-auc:0.85159
# [58]	train-auc:0.96564	valid-auc:0.85162
# [59]	train-auc:0.96668	valid-auc:0.85146
# [60]	train-auc:0.96802	valid-auc:0.85183
# [61]	train-auc:0.96907	valid-auc:0.85168
# [62]	train-auc:0.97001	valid-auc:0.85222
# [63]	train-auc:0.97109	valid-auc:0.85199
# [64]	train-auc:0.97208	valid-auc:0.85184
# [65]	train-auc:0.97287	valid-auc:0.85329
# [66]	train-auc:0.97371	valid-auc:0.85313
# [67]	train-auc:0.97433	valid-auc:0.85473
# [68]	train-auc:0.97513	valid-auc:0.85473
# [69]	train-auc:0.97607	valid-auc:0.85425
# [70]	train-auc:0.97643	valid-auc:0.85375
# [71]	train-auc:0.97745	valid-auc:0.85390
# [72]	train-auc:0.97811	valid-auc:0.85388
# [73]	train-auc:0.97905	valid-auc:0.85431
# [74]	train-auc:0.97982	valid-auc:0.85546
# [75]	train-auc:0.98018	valid-auc:0.85634
# [76]	train-auc:0.98086	valid-auc:0.85666
# [77]	train-auc:0.98134	valid-auc:0.85699
# [78]	train-auc:0.98198	valid-auc:0.85693
# [79]	train-auc:0.98267	valid-auc:0.85830
# [80]	train-auc:0.98298	valid-auc:0.85755
# [81]	train-auc:0.98358	valid-auc:0.85769
# [82]	train-auc:0.98429	valid-auc:0.85662
# [83]	train-auc:0.98471	valid-auc:0.85721
# [84]	train-auc:0.98525	valid-auc:0.85666
# [85]	train-auc:0.98559	valid-auc:0.85741
# [86]	train-auc:0.98615	valid-auc:0.85785
# [87]	train-auc:0.98663	valid-auc:0.85695
# [88]	train-auc:0.98706	valid-auc:0.85705
# [89]	train-auc:0.98751	valid-auc:0.85732
# [90]	train-auc:0.98801	valid-auc:0.85762
# [91]	train-auc:0.98841	valid-auc:0.85779
# [92]	train-auc:0.98925	valid-auc:0.85864
# [93]	train-auc:0.98963	valid-auc:0.85914
# [94]	train-auc:0.98980	valid-auc:0.85912
# [95]	train-auc:0.99028	valid-auc:0.85961
# [96]	train-auc:0.99083	valid-auc:0.86013
# [97]	train-auc:0.99098	valid-auc:0.85956
# [98]	train-auc:0.99153	valid-auc:0.85951
# [99]	train-auc:0.99210	valid-auc:0.86082
# [100]	train-auc:0.99249	valid-auc:0.86230
# [101]	train-auc:0.99278	valid-auc:0.86180
# [102]	train-auc:0.99296	valid-auc:0.86143
# [103]	train-auc:0.99324	valid-auc:0.86101
# [104]	train-auc:0.99336	valid-auc:0.86181
# [105]	train-auc:0.99376	valid-auc:0.86207
# [106]	train-auc:0.99419	valid-auc:0.86210
# [107]	train-auc:0.99435	valid-auc:0.86200
# [108]	train-auc:0.99443	valid-auc:0.86209
# [109]	train-auc:0.99451	valid-auc:0.86237
# [110]	train-auc:0.99465	valid-auc:0.86182
# [111]	train-auc:0.99487	valid-auc:0.86293
# [112]	train-auc:0.99505	valid-auc:0.86297
# [113]	train-auc:0.99538	valid-auc:0.86240
# [114]	train-auc:0.99564	valid-auc:0.86189
# [115]	train-auc:0.99572	valid-auc:0.86205
# [116]	train-auc:0.99594	valid-auc:0.86230
# [117]	train-auc:0.99606	valid-auc:0.86228
# [118]	train-auc:0.99632	valid-auc:0.86192
# [119]	train-auc:0.99645	valid-auc:0.86202
# [120]	train-auc:0.99664	valid-auc:0.86262
# [121]	train-auc:0.99689	valid-auc:0.86243
# [122]	train-auc:0.99703	valid-auc:0.86224
# [123]	train-auc:0.99717	valid-auc:0.86162
# [124]	train-auc:0.99731	valid-auc:0.86171
# [125]	train-auc:0.99739	valid-auc:0.86223
# [126]	train-auc:0.99750	valid-auc:0.86235
# [127]	train-auc:0.99756	valid-auc:0.86250
# [128]	train-auc:0.99775	valid-auc:0.86337
# [129]	train-auc:0.99784	valid-auc:0.86370
# [130]	train-auc:0.99796	valid-auc:0.86373
# [131]	train-auc:0.99815	valid-auc:0.86246
# [132]	train-auc:0.99820	valid-auc:0.86273
# [133]	train-auc:0.99835	valid-auc:0.86266
# [134]	train-auc:0.99841	valid-auc:0.86290
# [135]	train-auc:0.99854	valid-auc:0.86348
# [136]	train-auc:0.99860	valid-auc:0.86282
# [137]	train-auc:0.99870	valid-auc:0.86281
# [138]	train-auc:0.99872	valid-auc:0.86278
# [139]	train-auc:0.99874	valid-auc:0.86315
# [140]	train-auc:0.99876	valid-auc:0.86297
# [141]	train-auc:0.99882	valid-auc:0.86286
# [142]	train-auc:0.99887	valid-auc:0.86320
# [143]	train-auc:0.99889	valid-auc:0.86321
# [144]	train-auc:0.99895	valid-auc:0.86294
# [145]	train-auc:0.99899	valid-auc:0.86289
# [146]	train-auc:0.99905	valid-auc:0.86253
# [147]	train-auc:0.99909	valid-auc:0.86270
# [148]	train-auc:0.99916	valid-auc:0.86265
# [149]	train-auc:0.99921	valid-auc:0.86250
# [150]	train-auc:0.99930	valid-auc:0.86327
# Stopping. Best iteration:
# [130]	train-auc:0.99796	valid-auc:0.86373

# %%
submission = pd.concat([submid, pd.DataFrame(preds, columns = col)], axis=1)
submission.to_csv('sample_submission_FastText_xgb.csv', index=False)
