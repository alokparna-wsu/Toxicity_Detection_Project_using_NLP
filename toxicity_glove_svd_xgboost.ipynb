# %%
import numpy as np
import pandas as pd
import re, string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC
import xgboost as xgb
import gc
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy
import multiprocessing

# %%
dtypes = {
    'comment_text'   : np.unicode ,
    'toxic':         np.int16, 
    'severe_toxic': np.int16,
    'obscene': np.int16,
    'threat': np.int16,
    'insult': np.int16,
    'identity_hate': np.int16
}

train = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/train.csv', dtype=dtypes, encoding='utf-8')
test = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/test.csv', dtype=dtypes, encoding='utf-8')

train.comment_text.fillna("unknown", inplace=True)
test.comment_text.fillna("unknown",  inplace=True)

subm = pd.read_csv('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/sample_submission.csv')    
submid = pd.DataFrame({'id': subm["id"].values.astype(str)}, dtype=np.str)

# %%
# Tokenization

re_tok = re.compile(u'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')

def tokenize(s):
    return re_tok.sub(r' \1 ', s).split()

# %%
# # These features are borrowed from https://www.kaggle.com/eikedehling/feature-engineering

# for element in data:
#     element['total_length'] = element['comment_text'].apply(len)
#     element['capitals'] = element['comment_text'].apply(lambda comment: sum(1 for c in comment if c.isupper()))
#     element['caps_vs_length'] = element.apply(lambda row: float(row['capitals'])/float(row['total_length']), axis=1)
#     element['num_exclamation_marks'] = element['comment_text'].apply(lambda comment: comment.count('!'))
#     element['num_question_marks'] = element['comment_text'].apply(lambda comment: comment.count('?'))
#     element['num_punctuation'] = element['comment_text'].apply(lambda comment: sum(comment.count(w) for w in '.,;:'))
#     element['num_symbols'] = element['comment_text'].apply(lambda comment: sum(comment.count(w) for w in '*&$%'))
#     element['num_words'] = element['comment_text'].apply(lambda comment: len(comment.split()))
#     element['num_unique_words'] = element['comment_text'].apply(lambda comment: len(set(w for w in comment.split())))
#     element['words_vs_unique'] = element['num_unique_words'] / element['num_words']
#     element['num_smilies'] = element['comment_text'].apply(lambda comment: sum(comment.count(w) for w in (':-)', ':)', ';-)', ';)')))
    
# col = ['total_length', 'capitals', 'caps_vs_length',
#        'num_exclamation_marks', 'num_question_marks', 'num_punctuation',
#        'num_symbols', 'num_words', 'num_unique_words', 'words_vs_unique',
#        'num_smilies']

# columns = ('toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate')

# %% [markdown]
# ### GloVe Word Vectors

# %%
train_mes, valid_mes, train_l, valid_l = train_test_split(train['comment_text'],
                                                          train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']],
                                                          test_size=0.2, random_state=42)
train_mes = pd.DataFrame(train_mes)
valid_mes = pd.DataFrame(valid_mes)

# %%
# load the GloVe vectors in a dictionary:

embeddings_index = {}
f = open('C:/Users/abandyop/Desktop/Personal/Data Mining/Project/Data17/glove.6B.300d.txt', encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    try:
        coefs = np.asarray(values[1:], dtype='float32')
    except:
        continue
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
# Function to create a normalized vector for the whole sentence
def sent2vec(s, embeddings_index):
    words = str(s).lower()
    words = tokenize(words)
    words = [w for w in words if w.isalpha()]
    M = []
    for w in words:
        try:
            M.append(embeddings_index[w])
        except:
            continue
    M = np.array(M)
    v = M.sum(axis=0)
    if type(v) != np.ndarray:
        return np.zeros(300)
    return v / np.sqrt((v ** 2).sum())

# %%
gc.collect()

# Create sentence vectors using the above function for training and validation set
xtrain_glove = [sent2vec(x, embeddings_index) for x in train_mes['comment_text']]
xvalid_glove = [sent2vec(x, embeddings_index) for x in valid_mes['comment_text']]

xtrain_glove = np.array(xtrain_glove)
xvalid_glove = np.array(xvalid_glove)

print("xtrain_glove.shape = ", xtrain_glove.shape)
print("xvalid_glove.shape = ", xvalid_glove.shape)

# Generate Word vectors of test data
xtest_glove = [sent2vec(x, embeddings_index) for x in test['comment_text']]
xtest_glove = np.array(xtest_glove)
# Out:
# xtrain_glove.shape =  (127656, 300)
# xvalid_glove.shape =  (31915, 300)

# %% [markdown]
# ### SGD Classifier

# %%
scores = []
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((valid_mes.shape[0], len(col))).astype(object)

for i, class_name in enumerate(col):
    print('fit '+ class_name)
    classifier = SGDClassifier(loss='log', max_iter=1000, epsilon=0.001, n_jobs=-1)

    cv_score = np.mean(cross_val_score(classifier, xtrain_glove, train_l[class_name], cv=5, scoring='roc_auc'))
    scores.append(cv_score)
    print('CV score for class {} is {}'.format(class_name, cv_score))

    classifier.fit(xtrain_glove, train_l[class_name])
    preds[:,i] = classifier.predict_proba(xvalid_glove)[:,1]
    
print('Total CV score is {}'.format(np.mean(scores)))
# Out:
# fit toxic
# CV score for class toxic is 0.7774531814868076
# fit severe_toxic
# CV score for class severe_toxic is 0.9029774888695542
# fit obscene
# CV score for class obscene is 0.8209661656956003
# fit threat
# CV score for class threat is 0.8490649348881352
# fit insult
# CV score for class insult is 0.8179873710268509
# fit identity_hate
# CV score for class identity_hate is 0.8150334304469109
# Total CV score is 0.8305804287356432

# %%
testpreds_glove = np.zeros((test.shape[0], len(col)))
for i, class_name in enumerate(col):
    print('fit '+ class_name)
    testpreds_glove[:,i] = classifier.predict_proba(xtest_glove)[:,1]
    
submission = pd.concat([submid, pd.DataFrame(testpreds_glove, columns = col)], axis=1)
submission.to_csv('sample_submission_glove_sgd.csv', index=False)
# Out:
# fit toxic
# fit severe_toxic
# fit obscene
# fit threat
# fit insult
# fit identity_hate

# %% [markdown]
# ### Logistic Regression Classifier

# %%
scores = []
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((valid_mes.shape[0], len(col))).astype(object)

for i, class_name in enumerate(col):
    print('fit '+ class_name)
    classifier = LogisticRegression(C=0.1, solver='sag')
#    classifier = SVC(C=1.0, probability=True)

    cv_score = np.mean(cross_val_score(classifier, xtrain_glove, train_l[class_name], cv=5, scoring='roc_auc'))
    scores.append(cv_score)
    print('CV score for class {} is {}'.format(class_name, cv_score))

    classifier.fit(xtrain_glove, train_l[class_name])
    preds[:,i] = classifier.predict_proba(xvalid_glove)[:,1]
    
print('Total CV score is {}'.format(np.mean(scores)))
# Out:
# fit toxic
# CV score for class toxic is 0.7777078113054194
# fit severe_toxic
# CV score for class severe_toxic is 0.9031895790677194
# fit obscene
# CV score for class obscene is 0.8212190814446563
# fit threat
# CV score for class threat is 0.8493295229506594
# fit insult
# CV score for class insult is 0.81829666476496
# fit identity_hate
# CV score for class identity_hate is 0.8151084490817322
# Total CV score is 0.8308085181025243

# %%
testpreds_glove = np.zeros((test.shape[0], len(col)))
for i, class_name in enumerate(col):
    print('fit '+ class_name)
    testpreds_glove[:,i] = classifier.predict_proba(xtest_glove)[:,1]
    
submission = pd.concat([submid, pd.DataFrame(testpreds_glove, columns = col)], axis=1)
submission.to_csv('sample_submission_glove_logit.csv', index=False)
# Out:
# fit toxic
# fit severe_toxic
# fit obscene
# fit threat
# fit insult
# fit identity_hate

# %% [markdown]
# ### XGBoost Classifier

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=2017, num_rounds=500):
    param = {}
    param['objective'] = 'binary:logistic'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['eval_metric'] = 'auc'
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'valid') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    return model

# %%
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((test.shape[0], len(col)))

for i, j in enumerate(col):
    print('fit '+j)
    model = runXGB(xtrain_glove, train_l[j], xvalid_glove, valid_l[j])
    preds[:,i] = model.predict(xgb.DMatrix(xtest_glove), ntree_limit = model.best_ntree_limit)
    gc.collect()
# Out:
# fit toxic
# [0]	train-auc:0.77183	valid-auc:0.76191
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.79460	valid-auc:0.78366
# [2]	train-auc:0.80376	valid-auc:0.79042
# [3]	train-auc:0.80897	valid-auc:0.79461
# [4]	train-auc:0.81179	valid-auc:0.79642
# [5]	train-auc:0.81391	valid-auc:0.79725
# [6]	train-auc:0.81632	valid-auc:0.79908
# [7]	train-auc:0.81831	valid-auc:0.80098
# [8]	train-auc:0.82029	valid-auc:0.80279
# [9]	train-auc:0.82166	valid-auc:0.80347
# [10]	train-auc:0.82321	valid-auc:0.80401
# [11]	train-auc:0.82420	valid-auc:0.80505
# [12]	train-auc:0.82610	valid-auc:0.80594
# [13]	train-auc:0.82753	valid-auc:0.80681
# [14]	train-auc:0.82893	valid-auc:0.80813
# [15]	train-auc:0.83034	valid-auc:0.80803
# [16]	train-auc:0.83161	valid-auc:0.80883
# [17]	train-auc:0.83289	valid-auc:0.80936
# [18]	train-auc:0.83432	valid-auc:0.81016
# [19]	train-auc:0.83593	valid-auc:0.81071
# [20]	train-auc:0.83703	valid-auc:0.81095
# [21]	train-auc:0.83858	valid-auc:0.81230
# [22]	train-auc:0.84014	valid-auc:0.81262
# [23]	train-auc:0.84144	valid-auc:0.81357
# [24]	train-auc:0.84271	valid-auc:0.81452
# [25]	train-auc:0.84393	valid-auc:0.81547
# [26]	train-auc:0.84533	valid-auc:0.81624
# [27]	train-auc:0.84682	valid-auc:0.81764
# [28]	train-auc:0.84824	valid-auc:0.81821
# [29]	train-auc:0.84952	valid-auc:0.81881
# [30]	train-auc:0.85081	valid-auc:0.81931
# [31]	train-auc:0.85238	valid-auc:0.82001
# [32]	train-auc:0.85365	valid-auc:0.82094
# [33]	train-auc:0.85493	valid-auc:0.82147
# [34]	train-auc:0.85657	valid-auc:0.82189
# [35]	train-auc:0.85777	valid-auc:0.82232
# [36]	train-auc:0.85918	valid-auc:0.82303
# [37]	train-auc:0.86040	valid-auc:0.82376
# [38]	train-auc:0.86160	valid-auc:0.82414
# [39]	train-auc:0.86265	valid-auc:0.82482
# [40]	train-auc:0.86380	valid-auc:0.82541
# [41]	train-auc:0.86527	valid-auc:0.82630
# [42]	train-auc:0.86666	valid-auc:0.82725
# [43]	train-auc:0.86794	valid-auc:0.82822
# [44]	train-auc:0.86888	valid-auc:0.82862
# [45]	train-auc:0.87001	valid-auc:0.82922
# [46]	train-auc:0.87111	valid-auc:0.82978
# [47]	train-auc:0.87235	valid-auc:0.83052
# [48]	train-auc:0.87339	valid-auc:0.83062
# [49]	train-auc:0.87457	valid-auc:0.83090
# [50]	train-auc:0.87569	valid-auc:0.83159
# [51]	train-auc:0.87649	valid-auc:0.83168
# [52]	train-auc:0.87772	valid-auc:0.83224
# [53]	train-auc:0.87874	valid-auc:0.83261
# [54]	train-auc:0.87977	valid-auc:0.83307
# [55]	train-auc:0.88092	valid-auc:0.83339
# [56]	train-auc:0.88165	valid-auc:0.83382
# [57]	train-auc:0.88211	valid-auc:0.83382
# [58]	train-auc:0.88298	valid-auc:0.83415
# [59]	train-auc:0.88388	valid-auc:0.83452
# [60]	train-auc:0.88465	valid-auc:0.83489
# [61]	train-auc:0.88540	valid-auc:0.83514
# [62]	train-auc:0.88630	valid-auc:0.83538
# [63]	train-auc:0.88717	valid-auc:0.83582
# [64]	train-auc:0.88801	valid-auc:0.83630
# [65]	train-auc:0.88900	valid-auc:0.83629
# [66]	train-auc:0.88983	valid-auc:0.83661
# [67]	train-auc:0.89057	valid-auc:0.83708
# [68]	train-auc:0.89149	valid-auc:0.83749
# [69]	train-auc:0.89258	valid-auc:0.83783
# [70]	train-auc:0.89326	valid-auc:0.83800
# [71]	train-auc:0.89396	valid-auc:0.83849
# [72]	train-auc:0.89463	valid-auc:0.83876
# [73]	train-auc:0.89535	valid-auc:0.83883
# [74]	train-auc:0.89597	valid-auc:0.83894
# [75]	train-auc:0.89680	valid-auc:0.83906
# [76]	train-auc:0.89744	valid-auc:0.83919
# [77]	train-auc:0.89808	valid-auc:0.83950
# [78]	train-auc:0.89848	valid-auc:0.83969
# [79]	train-auc:0.89892	valid-auc:0.83965
# [80]	train-auc:0.89956	valid-auc:0.83966
# [81]	train-auc:0.90016	valid-auc:0.83964
# [82]	train-auc:0.90094	valid-auc:0.83976
# [83]	train-auc:0.90153	valid-auc:0.83959
# [84]	train-auc:0.90230	valid-auc:0.83983
# [85]	train-auc:0.90288	valid-auc:0.83995
# [86]	train-auc:0.90361	valid-auc:0.84026
# [87]	train-auc:0.90431	valid-auc:0.84065
# [88]	train-auc:0.90473	valid-auc:0.84070
# [89]	train-auc:0.90547	valid-auc:0.84081
# [90]	train-auc:0.90596	valid-auc:0.84086
# [91]	train-auc:0.90652	valid-auc:0.84107
# [92]	train-auc:0.90724	valid-auc:0.84127
# [93]	train-auc:0.90788	valid-auc:0.84151
# [94]	train-auc:0.90836	valid-auc:0.84167
# [95]	train-auc:0.90860	valid-auc:0.84172
# [96]	train-auc:0.90933	valid-auc:0.84201
# [97]	train-auc:0.90974	valid-auc:0.84226
# [98]	train-auc:0.91036	valid-auc:0.84247
# [99]	train-auc:0.91111	valid-auc:0.84264
# [100]	train-auc:0.91142	valid-auc:0.84283
# [101]	train-auc:0.91173	valid-auc:0.84306
# [102]	train-auc:0.91220	valid-auc:0.84312
# [103]	train-auc:0.91267	valid-auc:0.84305
# [104]	train-auc:0.91318	valid-auc:0.84326
# [105]	train-auc:0.91369	valid-auc:0.84337
# [106]	train-auc:0.91411	valid-auc:0.84353
# [107]	train-auc:0.91449	valid-auc:0.84353
# [108]	train-auc:0.91493	valid-auc:0.84355
# [109]	train-auc:0.91549	valid-auc:0.84359
# [110]	train-auc:0.91595	valid-auc:0.84379
# [111]	train-auc:0.91626	valid-auc:0.84378
# [112]	train-auc:0.91684	valid-auc:0.84391
# [113]	train-auc:0.91716	valid-auc:0.84388
# [114]	train-auc:0.91749	valid-auc:0.84398
# [115]	train-auc:0.91791	valid-auc:0.84404
# [116]	train-auc:0.91850	valid-auc:0.84414
# [117]	train-auc:0.91909	valid-auc:0.84428
# [118]	train-auc:0.91928	valid-auc:0.84419
# [119]	train-auc:0.91957	valid-auc:0.84427
# [120]	train-auc:0.92029	valid-auc:0.84446
# [121]	train-auc:0.92063	valid-auc:0.84460
# [122]	train-auc:0.92117	valid-auc:0.84486
# [123]	train-auc:0.92173	valid-auc:0.84490
# [124]	train-auc:0.92217	valid-auc:0.84499
# [125]	train-auc:0.92234	valid-auc:0.84519
# [126]	train-auc:0.92274	valid-auc:0.84527
# [127]	train-auc:0.92337	valid-auc:0.84562
# [128]	train-auc:0.92376	valid-auc:0.84570
# [129]	train-auc:0.92417	valid-auc:0.84568
# [130]	train-auc:0.92466	valid-auc:0.84565
# [131]	train-auc:0.92517	valid-auc:0.84539
# [132]	train-auc:0.92545	valid-auc:0.84538
# [133]	train-auc:0.92579	valid-auc:0.84550
# [134]	train-auc:0.92622	valid-auc:0.84554
# [135]	train-auc:0.92632	valid-auc:0.84556
# [136]	train-auc:0.92663	valid-auc:0.84573
# [137]	train-auc:0.92703	valid-auc:0.84590
# [138]	train-auc:0.92759	valid-auc:0.84585
# [139]	train-auc:0.92772	valid-auc:0.84587
# [140]	train-auc:0.92801	valid-auc:0.84587
# [141]	train-auc:0.92843	valid-auc:0.84601
# [142]	train-auc:0.92876	valid-auc:0.84613
# [143]	train-auc:0.92907	valid-auc:0.84625
# [144]	train-auc:0.92956	valid-auc:0.84623
# [145]	train-auc:0.92977	valid-auc:0.84629
# [146]	train-auc:0.93017	valid-auc:0.84645
# [147]	train-auc:0.93036	valid-auc:0.84645
# [148]	train-auc:0.93065	valid-auc:0.84641
# [149]	train-auc:0.93109	valid-auc:0.84655
# [150]	train-auc:0.93166	valid-auc:0.84671
# [151]	train-auc:0.93195	valid-auc:0.84678
# [152]	train-auc:0.93245	valid-auc:0.84673
# [153]	train-auc:0.93292	valid-auc:0.84654
# [154]	train-auc:0.93307	valid-auc:0.84672
# [155]	train-auc:0.93325	valid-auc:0.84681
# [156]	train-auc:0.93359	valid-auc:0.84679
# [157]	train-auc:0.93403	valid-auc:0.84684
# [158]	train-auc:0.93455	valid-auc:0.84695
# [159]	train-auc:0.93487	valid-auc:0.84693
# [160]	train-auc:0.93528	valid-auc:0.84720
# [161]	train-auc:0.93558	valid-auc:0.84722
# [162]	train-auc:0.93605	valid-auc:0.84718
# [163]	train-auc:0.93643	valid-auc:0.84718
# [164]	train-auc:0.93695	valid-auc:0.84722
# [165]	train-auc:0.93730	valid-auc:0.84727
# [166]	train-auc:0.93770	valid-auc:0.84743
# [167]	train-auc:0.93800	valid-auc:0.84762
# [168]	train-auc:0.93839	valid-auc:0.84764
# [169]	train-auc:0.93871	valid-auc:0.84774
# [170]	train-auc:0.93910	valid-auc:0.84772
# [171]	train-auc:0.93928	valid-auc:0.84762
# [172]	train-auc:0.93946	valid-auc:0.84765
# [173]	train-auc:0.93987	valid-auc:0.84781
# [174]	train-auc:0.94037	valid-auc:0.84796
# [175]	train-auc:0.94056	valid-auc:0.84807
# [176]	train-auc:0.94092	valid-auc:0.84796
# [177]	train-auc:0.94112	valid-auc:0.84801
# [178]	train-auc:0.94156	valid-auc:0.84804
# [179]	train-auc:0.94171	valid-auc:0.84814
# [180]	train-auc:0.94211	valid-auc:0.84801
# [181]	train-auc:0.94252	valid-auc:0.84811
# [182]	train-auc:0.94290	valid-auc:0.84817
# [183]	train-auc:0.94320	valid-auc:0.84816
# [184]	train-auc:0.94373	valid-auc:0.84815
# [185]	train-auc:0.94408	valid-auc:0.84802
# [186]	train-auc:0.94443	valid-auc:0.84794
# [187]	train-auc:0.94470	valid-auc:0.84791
# [188]	train-auc:0.94506	valid-auc:0.84802
# [189]	train-auc:0.94537	valid-auc:0.84793
# [190]	train-auc:0.94567	valid-auc:0.84793
# [191]	train-auc:0.94602	valid-auc:0.84793
# [192]	train-auc:0.94652	valid-auc:0.84813
# [193]	train-auc:0.94671	valid-auc:0.84811
# [194]	train-auc:0.94703	valid-auc:0.84815
# [195]	train-auc:0.94733	valid-auc:0.84846
# [196]	train-auc:0.94773	valid-auc:0.84848
# [197]	train-auc:0.94802	valid-auc:0.84842
# [198]	train-auc:0.94833	valid-auc:0.84835
# [199]	train-auc:0.94856	valid-auc:0.84844
# [200]	train-auc:0.94878	valid-auc:0.84826
# [201]	train-auc:0.94918	valid-auc:0.84808
# [202]	train-auc:0.94948	valid-auc:0.84811
# [203]	train-auc:0.94973	valid-auc:0.84812
# [204]	train-auc:0.94995	valid-auc:0.84825
# [205]	train-auc:0.95032	valid-auc:0.84843
# [206]	train-auc:0.95056	valid-auc:0.84827
# [207]	train-auc:0.95089	valid-auc:0.84827
# [208]	train-auc:0.95122	valid-auc:0.84850
# [209]	train-auc:0.95154	valid-auc:0.84845
# [210]	train-auc:0.95189	valid-auc:0.84855
# [211]	train-auc:0.95216	valid-auc:0.84839
# [212]	train-auc:0.95246	valid-auc:0.84848
# [213]	train-auc:0.95274	valid-auc:0.84857
# [214]	train-auc:0.95304	valid-auc:0.84856
# [215]	train-auc:0.95339	valid-auc:0.84845
# [216]	train-auc:0.95364	valid-auc:0.84856
# [217]	train-auc:0.95398	valid-auc:0.84865
# [218]	train-auc:0.95437	valid-auc:0.84878
# [219]	train-auc:0.95476	valid-auc:0.84876
# [220]	train-auc:0.95502	valid-auc:0.84882
# [221]	train-auc:0.95528	valid-auc:0.84876
# [222]	train-auc:0.95566	valid-auc:0.84879
# [223]	train-auc:0.95596	valid-auc:0.84891
# [224]	train-auc:0.95616	valid-auc:0.84887
# [225]	train-auc:0.95645	valid-auc:0.84880
# [226]	train-auc:0.95682	valid-auc:0.84872
# [227]	train-auc:0.95725	valid-auc:0.84871
# [228]	train-auc:0.95769	valid-auc:0.84870
# [229]	train-auc:0.95783	valid-auc:0.84882
# [230]	train-auc:0.95826	valid-auc:0.84891
# [231]	train-auc:0.95848	valid-auc:0.84899
# [232]	train-auc:0.95862	valid-auc:0.84885
# [233]	train-auc:0.95892	valid-auc:0.84878
# [234]	train-auc:0.95920	valid-auc:0.84882
# [235]	train-auc:0.95936	valid-auc:0.84873
# [236]	train-auc:0.95969	valid-auc:0.84888
# [237]	train-auc:0.96001	valid-auc:0.84883
# [238]	train-auc:0.96016	valid-auc:0.84877
# [239]	train-auc:0.96033	valid-auc:0.84874
# [240]	train-auc:0.96045	valid-auc:0.84878
# [241]	train-auc:0.96058	valid-auc:0.84876
# [242]	train-auc:0.96083	valid-auc:0.84867
# [243]	train-auc:0.96096	valid-auc:0.84877
# [244]	train-auc:0.96132	valid-auc:0.84873
# [245]	train-auc:0.96165	valid-auc:0.84881
# [246]	train-auc:0.96184	valid-auc:0.84857
# [247]	train-auc:0.96228	valid-auc:0.84864
# [248]	train-auc:0.96253	valid-auc:0.84865
# [249]	train-auc:0.96279	valid-auc:0.84876
# [250]	train-auc:0.96289	valid-auc:0.84868
# [251]	train-auc:0.96311	valid-auc:0.84859
# Stopping. Best iteration:
# [231]	train-auc:0.95848	valid-auc:0.84899
#
# fit severe_toxic
# [0]	train-auc:0.85997	valid-auc:0.84465
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.89998	valid-auc:0.87309
# [2]	train-auc:0.90112	valid-auc:0.87330
# [3]	train-auc:0.90920	valid-auc:0.87951
# [4]	train-auc:0.91774	valid-auc:0.88450
# [5]	train-auc:0.92194	valid-auc:0.88648
# [6]	train-auc:0.92340	valid-auc:0.88631
# [7]	train-auc:0.92517	valid-auc:0.88681
# [8]	train-auc:0.92585	valid-auc:0.88721
# [9]	train-auc:0.92750	valid-auc:0.88956
# [10]	train-auc:0.92852	valid-auc:0.89078
# [11]	train-auc:0.92941	valid-auc:0.89121
# [12]	train-auc:0.93041	valid-auc:0.89113
# [13]	train-auc:0.93506	valid-auc:0.89267
# [14]	train-auc:0.93638	valid-auc:0.89297
# [15]	train-auc:0.93760	valid-auc:0.89835
# [16]	train-auc:0.93844	valid-auc:0.89826
# [17]	train-auc:0.93998	valid-auc:0.89841
# [18]	train-auc:0.94137	valid-auc:0.90268
# [19]	train-auc:0.94252	valid-auc:0.90404
# [20]	train-auc:0.94350	valid-auc:0.90554
# [21]	train-auc:0.94884	valid-auc:0.90981
# [22]	train-auc:0.95125	valid-auc:0.91188
# [23]	train-auc:0.95245	valid-auc:0.91341
# [24]	train-auc:0.95355	valid-auc:0.91502
# [25]	train-auc:0.95593	valid-auc:0.91725
# [26]	train-auc:0.95695	valid-auc:0.91664
# [27]	train-auc:0.95865	valid-auc:0.91657
# [28]	train-auc:0.95992	valid-auc:0.91751
# [29]	train-auc:0.96093	valid-auc:0.91828
# [30]	train-auc:0.96162	valid-auc:0.92052
# [31]	train-auc:0.96334	valid-auc:0.92122
# [32]	train-auc:0.96518	valid-auc:0.92158
# [33]	train-auc:0.96605	valid-auc:0.92188
# [34]	train-auc:0.96680	valid-auc:0.92235
# [35]	train-auc:0.96798	valid-auc:0.92284
# [36]	train-auc:0.96910	valid-auc:0.92395
# [37]	train-auc:0.96987	valid-auc:0.92319
# [38]	train-auc:0.97033	valid-auc:0.92307
# [39]	train-auc:0.97108	valid-auc:0.92256
# [40]	train-auc:0.97225	valid-auc:0.92310
# [41]	train-auc:0.97279	valid-auc:0.92354
# [42]	train-auc:0.97348	valid-auc:0.92343
# [43]	train-auc:0.97445	valid-auc:0.92515
# [44]	train-auc:0.97514	valid-auc:0.92580
# [45]	train-auc:0.97570	valid-auc:0.92547
# [46]	train-auc:0.97688	valid-auc:0.92462
# [47]	train-auc:0.97729	valid-auc:0.92456
# [48]	train-auc:0.97792	valid-auc:0.92537
# [49]	train-auc:0.97945	valid-auc:0.92573
# [50]	train-auc:0.97980	valid-auc:0.92523
# [51]	train-auc:0.98069	valid-auc:0.92669
# [52]	train-auc:0.98117	valid-auc:0.92664
# [53]	train-auc:0.98164	valid-auc:0.92660
# [54]	train-auc:0.98223	valid-auc:0.92661
# [55]	train-auc:0.98285	valid-auc:0.92627
# [56]	train-auc:0.98423	valid-auc:0.92605
# [57]	train-auc:0.98478	valid-auc:0.92850
# [58]	train-auc:0.98556	valid-auc:0.92884
# [59]	train-auc:0.98597	valid-auc:0.92931
# [60]	train-auc:0.98636	valid-auc:0.93003
# [61]	train-auc:0.98680	valid-auc:0.93001
# [62]	train-auc:0.98700	valid-auc:0.92986
# [63]	train-auc:0.98742	valid-auc:0.92949
# [64]	train-auc:0.98821	valid-auc:0.92939
# [65]	train-auc:0.98856	valid-auc:0.92941
# [66]	train-auc:0.98904	valid-auc:0.93056
# [67]	train-auc:0.98936	valid-auc:0.93181
# [68]	train-auc:0.98974	valid-auc:0.93139
# [69]	train-auc:0.99024	valid-auc:0.93098
# [70]	train-auc:0.99046	valid-auc:0.93167
# [71]	train-auc:0.99069	valid-auc:0.93092
# [72]	train-auc:0.99098	valid-auc:0.93106
# [73]	train-auc:0.99135	valid-auc:0.93148
# [74]	train-auc:0.99150	valid-auc:0.93173
# [75]	train-auc:0.99189	valid-auc:0.93273
# [76]	train-auc:0.99215	valid-auc:0.93289
# [77]	train-auc:0.99230	valid-auc:0.93312
# [78]	train-auc:0.99243	valid-auc:0.93351
# [79]	train-auc:0.99272	valid-auc:0.93404
# [80]	train-auc:0.99339	valid-auc:0.93465
# [81]	train-auc:0.99355	valid-auc:0.93476
# [82]	train-auc:0.99370	valid-auc:0.93509
# [83]	train-auc:0.99389	valid-auc:0.93546
# [84]	train-auc:0.99395	valid-auc:0.93601
# [85]	train-auc:0.99415	valid-auc:0.93599
# [86]	train-auc:0.99428	valid-auc:0.93600
# [87]	train-auc:0.99465	valid-auc:0.93724
# [88]	train-auc:0.99484	valid-auc:0.93757
# [89]	train-auc:0.99494	valid-auc:0.93776
# [90]	train-auc:0.99513	valid-auc:0.93771
# [91]	train-auc:0.99533	valid-auc:0.93767
# [92]	train-auc:0.99543	valid-auc:0.93743
# [93]	train-auc:0.99555	valid-auc:0.93747
# [94]	train-auc:0.99572	valid-auc:0.93719
# [95]	train-auc:0.99578	valid-auc:0.93713
# [96]	train-auc:0.99585	valid-auc:0.93683
# [97]	train-auc:0.99606	valid-auc:0.93650
# [98]	train-auc:0.99616	valid-auc:0.93645
# [99]	train-auc:0.99628	valid-auc:0.93630
# [100]	train-auc:0.99639	valid-auc:0.93664
# [101]	train-auc:0.99653	valid-auc:0.93641
# [102]	train-auc:0.99665	valid-auc:0.93603
# [103]	train-auc:0.99670	valid-auc:0.93579
# [104]	train-auc:0.99680	valid-auc:0.93583
# [105]	train-auc:0.99694	valid-auc:0.93615
# [106]	train-auc:0.99696	valid-auc:0.93615
# [107]	train-auc:0.99700	valid-auc:0.93624
# [108]	train-auc:0.99711	valid-auc:0.93656
# [109]	train-auc:0.99723	valid-auc:0.93657
# Stopping. Best iteration:
# [89]	train-auc:0.99494	valid-auc:0.93776
#
# fit obscene
# [0]	train-auc:0.80530	valid-auc:0.79090
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.82596	valid-auc:0.80949
# [2]	train-auc:0.83435	valid-auc:0.81805
# [3]	train-auc:0.83927	valid-auc:0.82249
# [4]	train-auc:0.84357	valid-auc:0.82584
# [5]	train-auc:0.84567	valid-auc:0.82777
# [6]	train-auc:0.84803	valid-auc:0.82939
# [7]	train-auc:0.85174	valid-auc:0.83191
# [8]	train-auc:0.85422	valid-auc:0.83486
# [9]	train-auc:0.85495	valid-auc:0.83480
# [10]	train-auc:0.85702	valid-auc:0.83654
# [11]	train-auc:0.85900	valid-auc:0.83658
# [12]	train-auc:0.86026	valid-auc:0.83721
# [13]	train-auc:0.86159	valid-auc:0.83898
# [14]	train-auc:0.86318	valid-auc:0.83915
# [15]	train-auc:0.86473	valid-auc:0.84011
# [16]	train-auc:0.86733	valid-auc:0.84143
# [17]	train-auc:0.86882	valid-auc:0.84209
# [18]	train-auc:0.86984	valid-auc:0.84245
# [19]	train-auc:0.87146	valid-auc:0.84360
# [20]	train-auc:0.87282	valid-auc:0.84424
# [21]	train-auc:0.87507	valid-auc:0.84523
# [22]	train-auc:0.87655	valid-auc:0.84609
# [23]	train-auc:0.87816	valid-auc:0.84740
# [24]	train-auc:0.88004	valid-auc:0.84882
# [25]	train-auc:0.88144	valid-auc:0.84946
# [26]	train-auc:0.88229	valid-auc:0.85014
# [27]	train-auc:0.88447	valid-auc:0.85120
# [28]	train-auc:0.88583	valid-auc:0.85206
# [29]	train-auc:0.88700	valid-auc:0.85271
# [30]	train-auc:0.88911	valid-auc:0.85347
# [31]	train-auc:0.89047	valid-auc:0.85407
# [32]	train-auc:0.89168	valid-auc:0.85488
# [33]	train-auc:0.89324	valid-auc:0.85540
# [34]	train-auc:0.89488	valid-auc:0.85640
# [35]	train-auc:0.89636	valid-auc:0.85750
# [36]	train-auc:0.89811	valid-auc:0.85833
# [37]	train-auc:0.89965	valid-auc:0.85883
# [38]	train-auc:0.90105	valid-auc:0.85967
# [39]	train-auc:0.90231	valid-auc:0.86042
# [40]	train-auc:0.90318	valid-auc:0.86082
# [41]	train-auc:0.90470	valid-auc:0.86207
# [42]	train-auc:0.90604	valid-auc:0.86281
# [43]	train-auc:0.90751	valid-auc:0.86381
# [44]	train-auc:0.90896	valid-auc:0.86458
# [45]	train-auc:0.91036	valid-auc:0.86541
# [46]	train-auc:0.91143	valid-auc:0.86562
# [47]	train-auc:0.91248	valid-auc:0.86615
# [48]	train-auc:0.91383	valid-auc:0.86664
# [49]	train-auc:0.91520	valid-auc:0.86795
# [50]	train-auc:0.91647	valid-auc:0.86863
# [51]	train-auc:0.91752	valid-auc:0.86943
# [52]	train-auc:0.91882	valid-auc:0.86955
# [53]	train-auc:0.91984	valid-auc:0.87016
# [54]	train-auc:0.92074	valid-auc:0.87090
# [55]	train-auc:0.92187	valid-auc:0.87102
# [56]	train-auc:0.92302	valid-auc:0.87134
# [57]	train-auc:0.92368	valid-auc:0.87189
# [58]	train-auc:0.92428	valid-auc:0.87227
# [59]	train-auc:0.92536	valid-auc:0.87281
# [60]	train-auc:0.92612	valid-auc:0.87325
# [61]	train-auc:0.92716	valid-auc:0.87359
# [62]	train-auc:0.92794	valid-auc:0.87430
# [63]	train-auc:0.92878	valid-auc:0.87460
# [64]	train-auc:0.92967	valid-auc:0.87521
# [65]	train-auc:0.93063	valid-auc:0.87546
# [66]	train-auc:0.93142	valid-auc:0.87546
# [67]	train-auc:0.93200	valid-auc:0.87560
# [68]	train-auc:0.93287	valid-auc:0.87595
# [69]	train-auc:0.93351	valid-auc:0.87616
# [70]	train-auc:0.93429	valid-auc:0.87657
# [71]	train-auc:0.93470	valid-auc:0.87674
# [72]	train-auc:0.93557	valid-auc:0.87697
# [73]	train-auc:0.93628	valid-auc:0.87721
# [74]	train-auc:0.93682	valid-auc:0.87723
# [75]	train-auc:0.93745	valid-auc:0.87726
# [76]	train-auc:0.93802	valid-auc:0.87741
# [77]	train-auc:0.93874	valid-auc:0.87747
# [78]	train-auc:0.93957	valid-auc:0.87787
# [79]	train-auc:0.94015	valid-auc:0.87823
# [80]	train-auc:0.94077	valid-auc:0.87829
# [81]	train-auc:0.94147	valid-auc:0.87843
# [82]	train-auc:0.94207	valid-auc:0.87872
# [83]	train-auc:0.94243	valid-auc:0.87846
# [84]	train-auc:0.94322	valid-auc:0.87876
# [85]	train-auc:0.94366	valid-auc:0.87891
# [86]	train-auc:0.94450	valid-auc:0.87921
# [87]	train-auc:0.94496	valid-auc:0.87920
# [88]	train-auc:0.94534	valid-auc:0.87931
# [89]	train-auc:0.94603	valid-auc:0.87949
# [90]	train-auc:0.94637	valid-auc:0.87931
# [91]	train-auc:0.94685	valid-auc:0.87930
# [92]	train-auc:0.94733	valid-auc:0.87946
# [93]	train-auc:0.94754	valid-auc:0.87961
# [94]	train-auc:0.94797	valid-auc:0.87950
# [95]	train-auc:0.94849	valid-auc:0.87974
# [96]	train-auc:0.94912	valid-auc:0.87965
# [97]	train-auc:0.94955	valid-auc:0.87984
# [98]	train-auc:0.94995	valid-auc:0.87986
# [99]	train-auc:0.95051	valid-auc:0.87969
# [100]	train-auc:0.95121	valid-auc:0.87975
# [101]	train-auc:0.95184	valid-auc:0.87979
# [102]	train-auc:0.95243	valid-auc:0.87992
# [103]	train-auc:0.95288	valid-auc:0.88013
# [104]	train-auc:0.95310	valid-auc:0.88010
# [105]	train-auc:0.95360	valid-auc:0.88027
# [106]	train-auc:0.95414	valid-auc:0.88031
# [107]	train-auc:0.95465	valid-auc:0.88042
# [108]	train-auc:0.95492	valid-auc:0.88035
# [109]	train-auc:0.95535	valid-auc:0.88054
# [110]	train-auc:0.95578	valid-auc:0.88067
# [111]	train-auc:0.95588	valid-auc:0.88067
# [112]	train-auc:0.95620	valid-auc:0.88075
# [113]	train-auc:0.95668	valid-auc:0.88092
# [114]	train-auc:0.95686	valid-auc:0.88087
# [115]	train-auc:0.95730	valid-auc:0.88075
# [116]	train-auc:0.95786	valid-auc:0.88041
# [117]	train-auc:0.95828	valid-auc:0.88021
# [118]	train-auc:0.95889	valid-auc:0.88024
# [119]	train-auc:0.95911	valid-auc:0.88017
# [120]	train-auc:0.95951	valid-auc:0.88024
# [121]	train-auc:0.95988	valid-auc:0.88050
# [122]	train-auc:0.96031	valid-auc:0.88058
# [123]	train-auc:0.96054	valid-auc:0.88059
# [124]	train-auc:0.96086	valid-auc:0.88052
# [125]	train-auc:0.96122	valid-auc:0.88046
# [126]	train-auc:0.96188	valid-auc:0.88051
# [127]	train-auc:0.96235	valid-auc:0.88044
# [128]	train-auc:0.96279	valid-auc:0.88058
# [129]	train-auc:0.96310	valid-auc:0.88040
# [130]	train-auc:0.96354	valid-auc:0.88019
# [131]	train-auc:0.96384	valid-auc:0.88024
# [132]	train-auc:0.96402	valid-auc:0.88023
# [133]	train-auc:0.96426	valid-auc:0.88022
# Stopping. Best iteration:
# [113]	train-auc:0.95668	valid-auc:0.88092
#
# fit threat
# [0]	train-auc:0.68161	valid-auc:0.65374
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.68469	valid-auc:0.65526
# [2]	train-auc:0.73821	valid-auc:0.72875
# [3]	train-auc:0.77173	valid-auc:0.77339
# [4]	train-auc:0.77112	valid-auc:0.77240
# [5]	train-auc:0.77740	valid-auc:0.77357
# [6]	train-auc:0.83704	valid-auc:0.81363
# [7]	train-auc:0.83754	valid-auc:0.81367
# [8]	train-auc:0.85091	valid-auc:0.84455
# [9]	train-auc:0.85344	valid-auc:0.84278
# [10]	train-auc:0.86817	valid-auc:0.87443
# [11]	train-auc:0.87782	valid-auc:0.87741
# [12]	train-auc:0.87731	valid-auc:0.87680
# [13]	train-auc:0.87821	valid-auc:0.87848
# [14]	train-auc:0.88190	valid-auc:0.88307
# [15]	train-auc:0.88334	valid-auc:0.88575
# [16]	train-auc:0.89269	valid-auc:0.88445
# [17]	train-auc:0.89558	valid-auc:0.88466
# [18]	train-auc:0.89686	valid-auc:0.88523
# [19]	train-auc:0.89950	valid-auc:0.88665
# [20]	train-auc:0.90152	valid-auc:0.90438
# [21]	train-auc:0.90309	valid-auc:0.90302
# [22]	train-auc:0.90690	valid-auc:0.90233
# [23]	train-auc:0.91185	valid-auc:0.90119
# [24]	train-auc:0.91949	valid-auc:0.91028
# [25]	train-auc:0.92465	valid-auc:0.90910
# [26]	train-auc:0.92593	valid-auc:0.90806
# [27]	train-auc:0.92782	valid-auc:0.90660
# [28]	train-auc:0.93135	valid-auc:0.90753
# [29]	train-auc:0.93189	valid-auc:0.90967
# [30]	train-auc:0.93445	valid-auc:0.90738
# [31]	train-auc:0.93952	valid-auc:0.90622
# [32]	train-auc:0.94217	valid-auc:0.90672
# [33]	train-auc:0.94305	valid-auc:0.90743
# [34]	train-auc:0.94837	valid-auc:0.90764
# [35]	train-auc:0.94914	valid-auc:0.90648
# [36]	train-auc:0.95103	valid-auc:0.90724
# [37]	train-auc:0.95172	valid-auc:0.91937
# [38]	train-auc:0.95595	valid-auc:0.92204
# [39]	train-auc:0.95665	valid-auc:0.92664
# [40]	train-auc:0.95798	valid-auc:0.92508
# [41]	train-auc:0.95944	valid-auc:0.92427
# [42]	train-auc:0.96076	valid-auc:0.92464
# [43]	train-auc:0.96232	valid-auc:0.92296
# [44]	train-auc:0.96389	valid-auc:0.92260
# [45]	train-auc:0.96471	valid-auc:0.92373
# [46]	train-auc:0.96684	valid-auc:0.92234
# [47]	train-auc:0.96895	valid-auc:0.92193
# [48]	train-auc:0.97084	valid-auc:0.92272
# [49]	train-auc:0.97237	valid-auc:0.92339
# [50]	train-auc:0.97524	valid-auc:0.92373
# [51]	train-auc:0.97583	valid-auc:0.92077
# [52]	train-auc:0.97620	valid-auc:0.92383
# [53]	train-auc:0.97712	valid-auc:0.92594
# [54]	train-auc:0.97737	valid-auc:0.92454
# [55]	train-auc:0.97829	valid-auc:0.92239
# [56]	train-auc:0.97995	valid-auc:0.92271
# [57]	train-auc:0.98139	valid-auc:0.92337
# [58]	train-auc:0.98234	valid-auc:0.92276
# [59]	train-auc:0.98239	valid-auc:0.92301
# Stopping. Best iteration:
# [39]	train-auc:0.95665	valid-auc:0.92664
#
# fit insult
# [0]	train-auc:0.80858	valid-auc:0.78738
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.83404	valid-auc:0.81320
# [2]	train-auc:0.84078	valid-auc:0.81856
# [3]	train-auc:0.84476	valid-auc:0.82210
# [4]	train-auc:0.85020	valid-auc:0.82673
# [5]	train-auc:0.85373	valid-auc:0.82920
# [6]	train-auc:0.85677	valid-auc:0.83220
# [7]	train-auc:0.85831	valid-auc:0.83310
# [8]	train-auc:0.86062	valid-auc:0.83359
# [9]	train-auc:0.86182	valid-auc:0.83376
# [10]	train-auc:0.86341	valid-auc:0.83499
# [11]	train-auc:0.86531	valid-auc:0.83605
# [12]	train-auc:0.86690	valid-auc:0.83632
# [13]	train-auc:0.86781	valid-auc:0.83688
# [14]	train-auc:0.86869	valid-auc:0.83753
# [15]	train-auc:0.87011	valid-auc:0.83847
# [16]	train-auc:0.87148	valid-auc:0.83898
# [17]	train-auc:0.87260	valid-auc:0.83905
# [18]	train-auc:0.87393	valid-auc:0.84082
# [19]	train-auc:0.87495	valid-auc:0.84126
# [20]	train-auc:0.87606	valid-auc:0.84149
# [21]	train-auc:0.87802	valid-auc:0.84197
# [22]	train-auc:0.88009	valid-auc:0.84177
# [23]	train-auc:0.88166	valid-auc:0.84274
# [24]	train-auc:0.88300	valid-auc:0.84391
# [25]	train-auc:0.88446	valid-auc:0.84575
# [26]	train-auc:0.88570	valid-auc:0.84657
# [27]	train-auc:0.88694	valid-auc:0.84705
# [28]	train-auc:0.88763	valid-auc:0.84730
# [29]	train-auc:0.88905	valid-auc:0.84791
# [30]	train-auc:0.89063	valid-auc:0.84878
# [31]	train-auc:0.89203	valid-auc:0.85027
# [32]	train-auc:0.89328	valid-auc:0.85113
# [33]	train-auc:0.89448	valid-auc:0.85198
# [34]	train-auc:0.89589	valid-auc:0.85285
# [35]	train-auc:0.89746	valid-auc:0.85318
# [36]	train-auc:0.89909	valid-auc:0.85388
# [37]	train-auc:0.90029	valid-auc:0.85443
# [38]	train-auc:0.90171	valid-auc:0.85533
# [39]	train-auc:0.90307	valid-auc:0.85584
# [40]	train-auc:0.90420	valid-auc:0.85660
# [41]	train-auc:0.90528	valid-auc:0.85698
# [42]	train-auc:0.90677	valid-auc:0.85796
# [43]	train-auc:0.90841	valid-auc:0.85849
# [44]	train-auc:0.90954	valid-auc:0.85922
# [45]	train-auc:0.91095	valid-auc:0.86034
# [46]	train-auc:0.91204	valid-auc:0.86047
# [47]	train-auc:0.91324	valid-auc:0.86126
# [48]	train-auc:0.91443	valid-auc:0.86133
# [49]	train-auc:0.91576	valid-auc:0.86137
# [50]	train-auc:0.91718	valid-auc:0.86248
# [51]	train-auc:0.91813	valid-auc:0.86271
# [52]	train-auc:0.91916	valid-auc:0.86336
# [53]	train-auc:0.91999	valid-auc:0.86396
# [54]	train-auc:0.92084	valid-auc:0.86411
# [55]	train-auc:0.92153	valid-auc:0.86434
# [56]	train-auc:0.92270	valid-auc:0.86464
# [57]	train-auc:0.92392	valid-auc:0.86503
# [58]	train-auc:0.92497	valid-auc:0.86505
# [59]	train-auc:0.92621	valid-auc:0.86546
# [60]	train-auc:0.92686	valid-auc:0.86590
# [61]	train-auc:0.92776	valid-auc:0.86644
# [62]	train-auc:0.92847	valid-auc:0.86679
# [63]	train-auc:0.92938	valid-auc:0.86714
# [64]	train-auc:0.93001	valid-auc:0.86748
# [65]	train-auc:0.93086	valid-auc:0.86780
# [66]	train-auc:0.93129	valid-auc:0.86808
# [67]	train-auc:0.93236	valid-auc:0.86808
# [68]	train-auc:0.93310	valid-auc:0.86823
# [69]	train-auc:0.93344	valid-auc:0.86865
# [70]	train-auc:0.93403	valid-auc:0.86887
# [71]	train-auc:0.93439	valid-auc:0.86911
# [72]	train-auc:0.93539	valid-auc:0.86935
# [73]	train-auc:0.93600	valid-auc:0.86962
# [74]	train-auc:0.93690	valid-auc:0.86984
# [75]	train-auc:0.93735	valid-auc:0.87018
# [76]	train-auc:0.93785	valid-auc:0.87025
# [77]	train-auc:0.93863	valid-auc:0.87037
# [78]	train-auc:0.93911	valid-auc:0.87055
# [79]	train-auc:0.93958	valid-auc:0.87056
# [80]	train-auc:0.94025	valid-auc:0.87083
# [81]	train-auc:0.94067	valid-auc:0.87092
# [82]	train-auc:0.94115	valid-auc:0.87107
# [83]	train-auc:0.94169	valid-auc:0.87131
# [84]	train-auc:0.94191	valid-auc:0.87138
# [85]	train-auc:0.94257	valid-auc:0.87102
# [86]	train-auc:0.94312	valid-auc:0.87129
# [87]	train-auc:0.94365	valid-auc:0.87169
# [88]	train-auc:0.94395	valid-auc:0.87181
# [89]	train-auc:0.94465	valid-auc:0.87172
# [90]	train-auc:0.94503	valid-auc:0.87195
# [91]	train-auc:0.94543	valid-auc:0.87198
# [92]	train-auc:0.94577	valid-auc:0.87204
# [93]	train-auc:0.94612	valid-auc:0.87196
# [94]	train-auc:0.94633	valid-auc:0.87209
# [95]	train-auc:0.94682	valid-auc:0.87222
# [96]	train-auc:0.94742	valid-auc:0.87255
# [97]	train-auc:0.94756	valid-auc:0.87257
# [98]	train-auc:0.94832	valid-auc:0.87247
# [99]	train-auc:0.94875	valid-auc:0.87230
# [100]	train-auc:0.94934	valid-auc:0.87238
# [101]	train-auc:0.94968	valid-auc:0.87225
# [102]	train-auc:0.95025	valid-auc:0.87264
# [103]	train-auc:0.95050	valid-auc:0.87278
# [104]	train-auc:0.95091	valid-auc:0.87289
# [105]	train-auc:0.95120	valid-auc:0.87295
# [106]	train-auc:0.95179	valid-auc:0.87325
# [107]	train-auc:0.95208	valid-auc:0.87331
# [108]	train-auc:0.95243	valid-auc:0.87344
# [109]	train-auc:0.95265	valid-auc:0.87333
# [110]	train-auc:0.95296	valid-auc:0.87330
# [111]	train-auc:0.95336	valid-auc:0.87356
# [112]	train-auc:0.95398	valid-auc:0.87350
# [113]	train-auc:0.95460	valid-auc:0.87362
# [114]	train-auc:0.95505	valid-auc:0.87362
# [115]	train-auc:0.95560	valid-auc:0.87337
# [116]	train-auc:0.95606	valid-auc:0.87326
# [117]	train-auc:0.95633	valid-auc:0.87335
# [118]	train-auc:0.95675	valid-auc:0.87343
# [119]	train-auc:0.95710	valid-auc:0.87362
# [120]	train-auc:0.95733	valid-auc:0.87396
# [121]	train-auc:0.95768	valid-auc:0.87407
# [122]	train-auc:0.95846	valid-auc:0.87410
# [123]	train-auc:0.95881	valid-auc:0.87415
# [124]	train-auc:0.95923	valid-auc:0.87398
# [125]	train-auc:0.95969	valid-auc:0.87405
# [126]	train-auc:0.96015	valid-auc:0.87401
# [127]	train-auc:0.96056	valid-auc:0.87408
# [128]	train-auc:0.96109	valid-auc:0.87421
# [129]	train-auc:0.96137	valid-auc:0.87406
# [130]	train-auc:0.96167	valid-auc:0.87401
# [131]	train-auc:0.96207	valid-auc:0.87407
# [132]	train-auc:0.96245	valid-auc:0.87397
# [133]	train-auc:0.96256	valid-auc:0.87387
# [134]	train-auc:0.96297	valid-auc:0.87391
# [135]	train-auc:0.96331	valid-auc:0.87403
# [136]	train-auc:0.96374	valid-auc:0.87417
# [137]	train-auc:0.96413	valid-auc:0.87442
# [138]	train-auc:0.96452	valid-auc:0.87456
# [139]	train-auc:0.96475	valid-auc:0.87486
# [140]	train-auc:0.96505	valid-auc:0.87489
# [141]	train-auc:0.96516	valid-auc:0.87483
# [142]	train-auc:0.96553	valid-auc:0.87489
# [143]	train-auc:0.96602	valid-auc:0.87494
# [144]	train-auc:0.96623	valid-auc:0.87504
# [145]	train-auc:0.96673	valid-auc:0.87525
# [146]	train-auc:0.96709	valid-auc:0.87552
# [147]	train-auc:0.96744	valid-auc:0.87556
# [148]	train-auc:0.96763	valid-auc:0.87568
# [149]	train-auc:0.96818	valid-auc:0.87563
# [150]	train-auc:0.96854	valid-auc:0.87578
# [151]	train-auc:0.96869	valid-auc:0.87575
# [152]	train-auc:0.96895	valid-auc:0.87587
# [153]	train-auc:0.96943	valid-auc:0.87589
# [154]	train-auc:0.96965	valid-auc:0.87600
# [155]	train-auc:0.96994	valid-auc:0.87597
# [156]	train-auc:0.97016	valid-auc:0.87577
# [157]	train-auc:0.97031	valid-auc:0.87580
# [158]	train-auc:0.97056	valid-auc:0.87583
# [159]	train-auc:0.97084	valid-auc:0.87574
# [160]	train-auc:0.97108	valid-auc:0.87570
# [161]	train-auc:0.97128	valid-auc:0.87577
# [162]	train-auc:0.97171	valid-auc:0.87584
# [163]	train-auc:0.97193	valid-auc:0.87575
# [164]	train-auc:0.97220	valid-auc:0.87594
# [165]	train-auc:0.97242	valid-auc:0.87594
# [166]	train-auc:0.97263	valid-auc:0.87601
# [167]	train-auc:0.97310	valid-auc:0.87608
# [168]	train-auc:0.97345	valid-auc:0.87607
# [169]	train-auc:0.97372	valid-auc:0.87611
# [170]	train-auc:0.97390	valid-auc:0.87625
# [171]	train-auc:0.97410	valid-auc:0.87630
# [172]	train-auc:0.97439	valid-auc:0.87622
# [173]	train-auc:0.97474	valid-auc:0.87620
# [174]	train-auc:0.97505	valid-auc:0.87607
# [175]	train-auc:0.97521	valid-auc:0.87618
# [176]	train-auc:0.97553	valid-auc:0.87626
# [177]	train-auc:0.97574	valid-auc:0.87624
# [178]	train-auc:0.97602	valid-auc:0.87632
# [179]	train-auc:0.97629	valid-auc:0.87644
# [180]	train-auc:0.97647	valid-auc:0.87643
# [181]	train-auc:0.97690	valid-auc:0.87633
# [182]	train-auc:0.97710	valid-auc:0.87633
# [183]	train-auc:0.97738	valid-auc:0.87612
# [184]	train-auc:0.97744	valid-auc:0.87616
# [185]	train-auc:0.97762	valid-auc:0.87619
# [186]	train-auc:0.97788	valid-auc:0.87631
# [187]	train-auc:0.97815	valid-auc:0.87641
# [188]	train-auc:0.97828	valid-auc:0.87638
# [189]	train-auc:0.97849	valid-auc:0.87639
# [190]	train-auc:0.97867	valid-auc:0.87648
# [191]	train-auc:0.97884	valid-auc:0.87652
# [192]	train-auc:0.97900	valid-auc:0.87642
# [193]	train-auc:0.97928	valid-auc:0.87648
# [194]	train-auc:0.97939	valid-auc:0.87637
# [195]	train-auc:0.97952	valid-auc:0.87633
# [196]	train-auc:0.97967	valid-auc:0.87627
# [197]	train-auc:0.97977	valid-auc:0.87620
# [198]	train-auc:0.97994	valid-auc:0.87622
# [199]	train-auc:0.98011	valid-auc:0.87624
# [200]	train-auc:0.98044	valid-auc:0.87656
# [201]	train-auc:0.98072	valid-auc:0.87659
# [202]	train-auc:0.98096	valid-auc:0.87664
# [203]	train-auc:0.98108	valid-auc:0.87666
# [204]	train-auc:0.98122	valid-auc:0.87655
# [205]	train-auc:0.98138	valid-auc:0.87671
# [206]	train-auc:0.98156	valid-auc:0.87693
# [207]	train-auc:0.98171	valid-auc:0.87674
# [208]	train-auc:0.98193	valid-auc:0.87670
# [209]	train-auc:0.98215	valid-auc:0.87683
# [210]	train-auc:0.98243	valid-auc:0.87668
# [211]	train-auc:0.98259	valid-auc:0.87642
# [212]	train-auc:0.98285	valid-auc:0.87656
# [213]	train-auc:0.98302	valid-auc:0.87645
# [214]	train-auc:0.98314	valid-auc:0.87649
# [215]	train-auc:0.98336	valid-auc:0.87635
# [216]	train-auc:0.98356	valid-auc:0.87634
# [217]	train-auc:0.98370	valid-auc:0.87624
# [218]	train-auc:0.98384	valid-auc:0.87601
# [219]	train-auc:0.98403	valid-auc:0.87584
# [220]	train-auc:0.98414	valid-auc:0.87585
# [221]	train-auc:0.98431	valid-auc:0.87592
# [222]	train-auc:0.98448	valid-auc:0.87577
# [223]	train-auc:0.98466	valid-auc:0.87574
# [224]	train-auc:0.98490	valid-auc:0.87577
# [225]	train-auc:0.98524	valid-auc:0.87583
# [226]	train-auc:0.98536	valid-auc:0.87610
# Stopping. Best iteration:
# [206]	train-auc:0.98156	valid-auc:0.87693
#
# fit identity_hate
# [0]	train-auc:0.76559	valid-auc:0.71291
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.80071	valid-auc:0.74973
# [2]	train-auc:0.81587	valid-auc:0.75536
# [3]	train-auc:0.81795	valid-auc:0.75788
# [4]	train-auc:0.82725	valid-auc:0.76088
# [5]	train-auc:0.82792	valid-auc:0.75889
# [6]	train-auc:0.83679	valid-auc:0.76590
# [7]	train-auc:0.84315	valid-auc:0.77440
# [8]	train-auc:0.84717	valid-auc:0.77453
# [9]	train-auc:0.84811	valid-auc:0.77730
# [10]	train-auc:0.85163	valid-auc:0.77987
# [11]	train-auc:0.85665	valid-auc:0.78362
# [12]	train-auc:0.86027	valid-auc:0.78485
# [13]	train-auc:0.85994	valid-auc:0.78408
# [14]	train-auc:0.86081	valid-auc:0.78509
# [15]	train-auc:0.86106	valid-auc:0.78556
# [16]	train-auc:0.86774	valid-auc:0.79084
# [17]	train-auc:0.87017	valid-auc:0.79144
# [18]	train-auc:0.87055	valid-auc:0.79108
# [19]	train-auc:0.87499	valid-auc:0.79002
# [20]	train-auc:0.87977	valid-auc:0.79122
# [21]	train-auc:0.88125	valid-auc:0.79344
# [22]	train-auc:0.88378	valid-auc:0.79368
# [23]	train-auc:0.88640	valid-auc:0.79338
# [24]	train-auc:0.88829	valid-auc:0.79733
# [25]	train-auc:0.89187	valid-auc:0.80096
# [26]	train-auc:0.89435	valid-auc:0.80339
# [27]	train-auc:0.89597	valid-auc:0.80389
# [28]	train-auc:0.90116	valid-auc:0.80628
# [29]	train-auc:0.90287	valid-auc:0.80437
# [30]	train-auc:0.90592	valid-auc:0.80505
# [31]	train-auc:0.90767	valid-auc:0.80656
# [32]	train-auc:0.91019	valid-auc:0.80763
# [33]	train-auc:0.91173	valid-auc:0.80924
# [34]	train-auc:0.91249	valid-auc:0.80834
# [35]	train-auc:0.91423	valid-auc:0.80850
# [36]	train-auc:0.91583	valid-auc:0.80766
# [37]	train-auc:0.91832	valid-auc:0.81280
# [38]	train-auc:0.92009	valid-auc:0.81293
# [39]	train-auc:0.92419	valid-auc:0.81471
# [40]	train-auc:0.92639	valid-auc:0.81456
# [41]	train-auc:0.92794	valid-auc:0.81362
# [42]	train-auc:0.92941	valid-auc:0.81426
# [43]	train-auc:0.93127	valid-auc:0.81615
# [44]	train-auc:0.93333	valid-auc:0.81602
# [45]	train-auc:0.93505	valid-auc:0.81766
# [46]	train-auc:0.93788	valid-auc:0.81835
# [47]	train-auc:0.93926	valid-auc:0.82323
# [48]	train-auc:0.94165	valid-auc:0.82411
# [49]	train-auc:0.94516	valid-auc:0.82482
# [50]	train-auc:0.94775	valid-auc:0.82629
# [51]	train-auc:0.95148	valid-auc:0.82706
# [52]	train-auc:0.95255	valid-auc:0.82826
# [53]	train-auc:0.95457	valid-auc:0.82942
# [54]	train-auc:0.95731	valid-auc:0.83055
# [55]	train-auc:0.95804	valid-auc:0.83158
# [56]	train-auc:0.96029	valid-auc:0.82963
# [57]	train-auc:0.96154	valid-auc:0.83092
# [58]	train-auc:0.96256	valid-auc:0.83178
# [59]	train-auc:0.96436	valid-auc:0.83348
# [60]	train-auc:0.96601	valid-auc:0.83422
# [61]	train-auc:0.96716	valid-auc:0.83339
# [62]	train-auc:0.96817	valid-auc:0.83460
# [63]	train-auc:0.96937	valid-auc:0.83608
# [64]	train-auc:0.97032	valid-auc:0.83716
# [65]	train-auc:0.97150	valid-auc:0.83928
# [66]	train-auc:0.97206	valid-auc:0.83813
# [67]	train-auc:0.97266	valid-auc:0.83823
# [68]	train-auc:0.97366	valid-auc:0.83908
# [69]	train-auc:0.97482	valid-auc:0.84044
# [70]	train-auc:0.97577	valid-auc:0.84132
# [71]	train-auc:0.97650	valid-auc:0.84108
# [72]	train-auc:0.97687	valid-auc:0.84129
# [73]	train-auc:0.97747	valid-auc:0.84291
# [74]	train-auc:0.97801	valid-auc:0.84238
# [75]	train-auc:0.97899	valid-auc:0.84261
# [76]	train-auc:0.97968	valid-auc:0.84206
# [77]	train-auc:0.97998	valid-auc:0.84216
# [78]	train-auc:0.98123	valid-auc:0.84249
# [79]	train-auc:0.98204	valid-auc:0.84280
# [80]	train-auc:0.98261	valid-auc:0.84345
# [81]	train-auc:0.98315	valid-auc:0.84352
# [82]	train-auc:0.98377	valid-auc:0.84227
# [83]	train-auc:0.98401	valid-auc:0.84214
# [84]	train-auc:0.98433	valid-auc:0.84266
# [85]	train-auc:0.98504	valid-auc:0.84424
# [86]	train-auc:0.98564	valid-auc:0.84358
# [87]	train-auc:0.98600	valid-auc:0.84368
# [88]	train-auc:0.98641	valid-auc:0.84448
# [89]	train-auc:0.98679	valid-auc:0.84542
# [90]	train-auc:0.98694	valid-auc:0.84474
# [91]	train-auc:0.98727	valid-auc:0.84495
# [92]	train-auc:0.98786	valid-auc:0.84413
# [93]	train-auc:0.98819	valid-auc:0.84456
# [94]	train-auc:0.98884	valid-auc:0.84443
# [95]	train-auc:0.98927	valid-auc:0.84615
# [96]	train-auc:0.98989	valid-auc:0.84773
# [97]	train-auc:0.99018	valid-auc:0.84761
# [98]	train-auc:0.99060	valid-auc:0.84818
# [99]	train-auc:0.99096	valid-auc:0.84822
# [100]	train-auc:0.99132	valid-auc:0.84800
# [101]	train-auc:0.99168	valid-auc:0.84829
# [102]	train-auc:0.99188	valid-auc:0.84801
# [103]	train-auc:0.99253	valid-auc:0.84838
# [104]	train-auc:0.99280	valid-auc:0.84864
# [105]	train-auc:0.99293	valid-auc:0.84822
# [106]	train-auc:0.99319	valid-auc:0.84863
# [107]	train-auc:0.99327	valid-auc:0.84875
# [108]	train-auc:0.99333	valid-auc:0.84853
# [109]	train-auc:0.99345	valid-auc:0.84854
# [110]	train-auc:0.99366	valid-auc:0.84910
# [111]	train-auc:0.99407	valid-auc:0.84922
# [112]	train-auc:0.99432	valid-auc:0.84942
# [113]	train-auc:0.99455	valid-auc:0.84950
# [114]	train-auc:0.99464	valid-auc:0.84986
# [115]	train-auc:0.99485	valid-auc:0.84973
# [116]	train-auc:0.99513	valid-auc:0.84941
# [117]	train-auc:0.99528	valid-auc:0.84891
# [118]	train-auc:0.99561	valid-auc:0.84938
# [119]	train-auc:0.99578	valid-auc:0.84929
# [120]	train-auc:0.99599	valid-auc:0.85010
# [121]	train-auc:0.99620	valid-auc:0.85004
# [122]	train-auc:0.99643	valid-auc:0.85080
# [123]	train-auc:0.99656	valid-auc:0.85012
# [124]	train-auc:0.99673	valid-auc:0.85066
# [125]	train-auc:0.99696	valid-auc:0.85057
# [126]	train-auc:0.99710	valid-auc:0.85085
# [127]	train-auc:0.99731	valid-auc:0.85109
# [128]	train-auc:0.99749	valid-auc:0.85079
# [129]	train-auc:0.99766	valid-auc:0.85056
# [130]	train-auc:0.99779	valid-auc:0.85111
# [131]	train-auc:0.99793	valid-auc:0.85286
# [132]	train-auc:0.99800	valid-auc:0.85334
# [133]	train-auc:0.99810	valid-auc:0.85325
# [134]	train-auc:0.99824	valid-auc:0.85289
# [135]	train-auc:0.99834	valid-auc:0.85304
# [136]	train-auc:0.99841	valid-auc:0.85186
# [137]	train-auc:0.99848	valid-auc:0.85147
# [138]	train-auc:0.99850	valid-auc:0.85099
# [139]	train-auc:0.99854	valid-auc:0.85107
# [140]	train-auc:0.99866	valid-auc:0.85134
# [141]	train-auc:0.99871	valid-auc:0.85186
# [142]	train-auc:0.99882	valid-auc:0.85190
# [143]	train-auc:0.99886	valid-auc:0.85102
# [144]	train-auc:0.99892	valid-auc:0.85149
# [145]	train-auc:0.99896	valid-auc:0.85076
# [146]	train-auc:0.99903	valid-auc:0.85004
# [147]	train-auc:0.99907	valid-auc:0.84969
# [148]	train-auc:0.99910	valid-auc:0.84979
# [149]	train-auc:0.99917	valid-auc:0.84984
# [150]	train-auc:0.99923	valid-auc:0.84917
# [151]	train-auc:0.99923	valid-auc:0.84929
# [152]	train-auc:0.99929	valid-auc:0.84907
# Stopping. Best iteration:
# [132]	train-auc:0.99800	valid-auc:0.85334

# %%
submission = pd.concat([submid, pd.DataFrame(preds, columns = col)], axis=1)
submission.to_csv('sample_submission_glove_xgb.csv', index=False)
